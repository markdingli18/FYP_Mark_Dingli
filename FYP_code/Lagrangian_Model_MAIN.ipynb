# %% [markdown]
# ### Importing Libraries

# %%
from parcels import FieldSet, Field, ParticleSet, JITParticle, AdvectionRK4
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from datetime import timedelta
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gpd
import rasterio
from rasterio.features import rasterize

# %% [markdown]
# ### Verifying the structure and dimentions of the data files

# %%
# Open the SSC dataset
ssc_ds = xr.open_dataset("Data/Processed_SSC_Data.nc")

# Print the SSC dataset
print("SSC Dataset:\n")
print(ssc_ds)
print("=" * 125)

# Open the wind dataset
wind_ds = xr.open_dataset("Data/Processed_Wind_Data.nc")

# Print the wind dataset
print("\nWind Dataset:\n")
print(wind_ds)
print("=" * 125)

# Close datasets after inspection
ssc_ds.close()
wind_ds.close()
# Out:
# SSC Dataset:
#
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 22, time: 2091)
# Coordinates:
#   * lat      (lat) float32 35.74 35.77 35.79 35.81 ... 36.21 36.23 36.26 36.28
#   * lon      (lon) float32 13.92 13.96 14.0 14.04 ... 14.65 14.69 14.73 14.77
#   * time     (time) datetime64[ns] 2021-01-01 2021-01-01T12:00:00 ... 2023-11-12
# Data variables:
#     u        (time, lat, lon) float64 ...
#     v        (time, lat, lon) float64 ...
#     stdu     (time, lat, lon) float64 ...
#     stdv     (time, lat, lon) float64 ...
#     cov      (time, lat, lon) float64 ...
#     velo     (time, lat, lon) float64 ...
#     head     (time, lat, lon) float64 ...
# Attributes: (12/17)
#     NC_GLOBAL.Title:                   Near-Real time Surface Ocean Velocity
#     NC_GLOBAL.origin:                  BARK (measured);POZZ (measured);
#     NC_GLOBAL.source:                  HF Radar Derived Surface Currents obta...
#     NC_GLOBAL.history:                 08-Jun-2023 14:46:23
#     NC_GLOBAL.grid_type:               REGULAR
#     NC_GLOBAL.Conventions:             CF-1.4
#     ...                                ...
#     NC_GLOBAL.grid_resolution:         3.0km
#     NC_GLOBAL.geospatial_lat_max:      36.8802
#     NC_GLOBAL.geospatial_lat_min:      35.7447
#     NC_GLOBAL.geospatial_lon_max:      15.3804
#     NC_GLOBAL.geospatial_lon_min:      13.6768
#     NC_GLOBAL.netcdf_library_version:  v2
# =============================================================================================================================
#
# Wind Dataset:
#
# <xarray.Dataset>
# Dimensions:    (longitude: 2, latitude: 2, time: 2091)
# Coordinates:
#   * longitude  (longitude) float32 14.1 14.5
#   * latitude   (latitude) float32 35.6 36.0
#   * time       (time) datetime64[ns] 2021-01-01 ... 2023-11-12
# Data variables:
#     v10        (time, latitude, longitude) float64 ...
#     u10        (time, latitude, longitude) float64 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-12-17 08:43:38 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# =============================================================================================================================

# %% [markdown]
# ### Load Shapefile and Extract Coastline Boundaries

# %%
# Load the shapefile
shapefile_path = 'Data/land_sea_mask/MaltaCoastline.shp'
gdf = gpd.read_file(shapefile_path)

# Plot the shapefile
gdf.plot(color='green')
plt.title('Malta Coastline')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ### Load Shapefile and Extract Coastline Boundaries

# %%
# Reproject to geographic coordinates (WGS 84)
gdf = gdf.to_crs(epsg=4326)

# Simulation bounds
lon_min, lat_min, lon_max, lat_max = 13.9, 35.6, 14.81, 36.3

# Define a finer resolution in kilometers
resolution_km = 0.8  # Finer resolution of 1 km

# Calculate the distance in degrees for the given resolution
mean_lat = (lat_min + lat_max) / 2
km_per_degree = np.cos(mean_lat * np.pi / 180) * 111.32  # Approximate conversion factor at this latitude
resolution_degrees = resolution_km / km_per_degree

# Calculate the number of grid cells at this new resolution
num_lons = int(np.ceil((lon_max - lon_min) / resolution_degrees))
num_lats = int(np.ceil((lat_max - lat_min) / resolution_degrees))

# Create the transformation from lat/lon to the grid
transform = rasterio.transform.from_origin(lon_min, lat_max, resolution_degrees, resolution_degrees)

# Rasterize the shapefile
raster = rasterize(
    [(geom, 1) for geom in gdf.geometry],
    out_shape=(num_lats, num_lons),
    transform=transform,
    fill=0,  # Fill value for 'sea'
    all_touched=True
)

# Generate the grid of longitude and latitude values
lons = np.linspace(lon_min, lon_max, num_lons, endpoint=False)
lats = np.linspace(lat_max, lat_min, num_lats, endpoint=False)[::-1]  # Start from max latitude to min latitude

# Create an xarray Dataset for the land-sea mask
ds = xr.Dataset(
    {
        'land_sea_mask': (['lat', 'lon'], raster)
    },
    coords={
        'lon': lons,
        'lat': lats  
    }
)

# Save the dataset to a NetCDF file
nc_filename = "Data/land_sea_mask/land_sea_mask_malta.nc"
ds.to_netcdf(nc_filename)

# Plot the land-sea mask for verification
plt.figure(figsize=(10, 8))
plt.pcolormesh(lons, lats[::-1], raster, cmap='viridis')
plt.colorbar(label='Land (1) / Sea (0)')
plt.title('Land-Sea Mask of Malta')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Overlay the shapefile to verify alignment
gdf.plot(ax=plt.gca(), color='none', edgecolor='red')

plt.show()

# %%
# # Load the land-sea mask data from the NetCDF file
# nc_filename = "Data/land_sea_mask/land_sea_mask_malta.nc"
# landsea_data = xr.open_dataset(nc_filename)

# # Extract the land-sea mask variable
# land_sea_mask = landsea_data['land_sea_mask']

# # Plotting
# fig = plt.figure(figsize=(10, 6))
# ax = plt.axes(projection=ccrs.PlateCarree())
# land_sea_mask.plot(ax=ax, x='lon', y='lat', transform=ccrs.PlateCarree(), cmap='viridis')

# # Add coastlines for reference
# ax.coastlines(resolution='10m', color='red', linewidth=1)
# ax.add_feature(cfeature.BORDERS, linestyle=':')
# ax.set_title('Land-Sea Mask of Malta')

# # Show the plot
# plt.show()

# %% [markdown]
# ### Creating a FieldSet

# %%
fieldset = FieldSet.from_netcdf(
    filenames={
        "U": "Data/Processed_SSC_Data.nc",
        "V": "Data/Processed_SSC_Data.nc",
        "U_wind": "Data/Processed_Wind_Data.nc",
        "V_wind": "Data/Processed_Wind_Data.nc"
    },
    variables={
        "U": "u",
        "V": "v",
        "U_wind": "u10",
        "V_wind": "v10"
    },
    dimensions={
        "U": {"lon": "lon", "lat": "lat", "time": "time"},
        "V": {"lon": "lon", "lat": "lat", "time": "time"},
        "U_wind": {"lon": "longitude", "lat": "latitude", "time": "time"},
        "V_wind": {"lon": "longitude", "lat": "latitude", "time": "time"}
    },
    allow_time_extrapolation=True
)

# Load the land-sea mask data
landsea_data = xr.open_dataset("Data/land_sea_mask/land_sea_mask_malta.nc")

# Add the land-sea mask as a Field to the FieldSet
fieldset.add_field(Field('land_sea_mask', 
                         data=landsea_data['land_sea_mask'].values, 
                         lon=landsea_data['lon'].values, 
                         lat=landsea_data['lat'].values, 
                         mesh='spherical', 
                         interp_method='nearest'))

# %% [markdown]
# ### Initializing the Particles

# %%
## Given polygon boundaries
#boundaries = {
#    'min_lon': 13.9, 'max_lon': 14.81,
#    'min_lat': 35.6, 'max_lat': 36.3
#}
#
## Calculate center of the polygon
#center_lon = (boundaries['min_lon'] + boundaries['max_lon']) / 2
#center_lat = (boundaries['min_lat'] + boundaries['max_lat']) / 2
#
## Define a range within which particles will be released around the center
## This will be a smaller area in the very center of your polygon
#range_lon = (boundaries['max_lon'] - boundaries['min_lon']) / 10  # 10% of the total longitude range
#range_lat = (boundaries['max_lat'] - boundaries['min_lat']) / 10  # 10% of the total latitude range
#
## Number of particles to release
#num_particles = 20
#
## Generate random positions within the central area
#lat_release = np.random.uniform(center_lat - range_lat, center_lat + range_lat, num_particles)
#lon_release = np.random.uniform(center_lon - range_lon, center_lon + range_lon, num_particles)
#
## Create a ParticleSet with JITParticle
#pset = ParticleSet(fieldset=fieldset, pclass=JITParticle, lon=lon_release, lat=lat_release)

# %%
# Define polygon boundaries
boundaries = {
    'min_lon': 13.9, 'max_lon': 14.81,
    'min_lat': 35.6, 'max_lat': 36.3
}

# Adjusting the release points to be closer to the edges of the boundary
edge_buffer_lon = (boundaries['max_lon'] - boundaries['min_lon']) / 20  # 5% buffer from the longitude edges
edge_buffer_lat = (boundaries['max_lat'] - boundaries['min_lat']) / 20  # 5% buffer from the latitude edges

# Number of particles to release
num_particles = 20

# Generate positions close to the edges
lat_release_near_edges = np.concatenate([
    np.random.uniform(boundaries['min_lat'] + edge_buffer_lat, boundaries['min_lat'] + 2 * edge_buffer_lat, num_particles // 4),
    np.random.uniform(boundaries['max_lat'] - 2 * edge_buffer_lat, boundaries['max_lat'] - edge_buffer_lat, num_particles // 4)
])

lon_release_near_edges = np.concatenate([
    np.random.uniform(boundaries['min_lon'] + edge_buffer_lon, boundaries['min_lon'] + 2 * edge_buffer_lon, num_particles // 4),
    np.random.uniform(boundaries['max_lon'] - 2 * edge_buffer_lon, boundaries['max_lon'] - edge_buffer_lon, num_particles // 4)
])

# To ensure even distribution, shuffle the arrays
np.random.shuffle(lat_release_near_edges)
np.random.shuffle(lon_release_near_edges)

# Since we divided the particles into groups for each edge, we might need to adjust if num_particles is not a multiple of 4
# This is a simple fix to ensure we have exactly num_particles
lat_release = np.resize(lat_release_near_edges, num_particles)
lon_release = np.resize(lon_release_near_edges, num_particles)

# Create a ParticleSet with JITParticle positioned near the edges
pset = ParticleSet(fieldset=fieldset, pclass=JITParticle, lon=lon_release, lat=lat_release)

# %% [markdown]
# ### Define Simulation Parameters

# %%
# Define number of days for the simulation
runtime = timedelta(days=1046)  

#--------------------------------------------------------------------------------------------------------------------------

# Option 1: Fixed timestep (e.g., 10 minutes)
# dt = timedelta(minutes=12)

# Option 2: Timestep that aligns with your data intervals (e.g., 30 minutes or 1 hour)
#dt = timedelta(minutes=30)
dt = timedelta(hours=12)

# Option 3: If you want to use the exact timestep as your data
# dt = timedelta(hours=12)  # if your data interval is 12 hours

# %% [markdown]
# ### Execute the Simulation

# %%
def CheckOutOfBounds(particle, fieldset, time):
    if particle.state == StatusCode.ErrorOutOfBounds:
        particle.delete()

def CheckError(particle, fieldset, time):
    if particle.state >= 50:  # This captures all Errors
        particle.delete()
        
# Define a custom kernel that deletes particles if they move onto land
def DeleteOnLand(particle, fieldset, time):
    if fieldset.land_sea_mask[particle] == 1:
        particle.delete()

# Execute the simulation
output_file = pset.ParticleFile(name="debris_simulation_output.zarr", outputdt=timedelta(minutes=720))  # Save output every hour
pset.execute(
    AdvectionRK4 + pset.Kernel(CheckOutOfBounds) + pset.Kernel(CheckError) + pset.Kernel(DeleteOnLand),  # Combine the advection kernel with the custom delete kernel
    runtime=runtime,
    dt=dt,
    output_file=output_file,
)
# Out:
# INFO: Output files are stored in debris_simulation_output.zarr.
#   0%|          | 0/90374400.0 [00:00<?, ?it/s]WARNING: ParticleSet is empty on writing as array at time 0
#   0%|          | 43200.0/90374400.0 [00:00<14:19, 105124.30it/s]WARNING: ParticleSet is empty on writing as array at time 43200
#   0%|          | 86400.0/90374400.0 [00:00<10:38, 141432.04it/s]WARNING: ParticleSet is empty on writing as array at time 86400
#   0%|          | 129600.0/90374400.0 [00:00<08:27, 177917.33it/s]WARNING: ParticleSet is empty on writing as array at time 129600
#   0%|          | 172800.0/90374400.0 [00:00<06:55, 217231.83it/s]WARNING: ParticleSet is empty on writing as array at time 172800
#   0%|          | 216000.0/90374400.0 [00:01<05:56, 253211.81it/s]WARNING: ParticleSet is empty on writing as array at time 216000
#   0%|          | 259200.0/90374400.0 [00:01<05:25, 276451.59it/s]WARNING: ParticleSet is empty on writing as array at time 259200
#   0%|          | 302400.0/90374400.0 [00:01<05:14, 286686.26it/s]WARNING: ParticleSet is empty on writing as array at time 302400
#   0%|          | 345600.0/90374400.0 [00:01<04:56, 303215.34it/s]WARNING: ParticleSet is empty on writing as array at time 345600
#   0%|          | 388800.0/90374400.0 [00:01<04:51, 308912.06it/s]WARNING: ParticleSet is empty on writing as array at time 388800
#   0%|          | 432000.0/90374400.0 [00:01<04:58, 301273.65it/s]WARNING: ParticleSet is empty on writing as array at time 432000
#   1%|          | 475200.0/90374400.0 [00:01<04:42, 318058.97it/s]WARNING: ParticleSet is empty on writing as array at time 475200
#   1%|          | 518400.0/90374400.0 [00:01<04:38, 322922.73it/s]WARNING: ParticleSet is empty on writing as array at time 518400
#   1%|          | 561600.0/90374400.0 [00:02<04:18, 347358.19it/s]WARNING: ParticleSet is empty on writing as array at time 561600
#   1%|          | 604800.0/90374400.0 [00:02<04:08, 361454.00it/s]WARNING: ParticleSet is empty on writing as array at time 604800
#   1%|          | 648000.0/90374400.0 [00:02<03:56, 378730.54it/s]WARNING: ParticleSet is empty on writing as array at time 648000
#   1%|          | 691200.0/90374400.0 [00:02<03:48, 393214.62it/s]WARNING: ParticleSet is empty on writing as array at time 691200
#   1%|          | 734400.0/90374400.0 [00:02<03:53, 384658.53it/s]WARNING: ParticleSet is empty on writing as array at time 734400
#   1%|          | 777600.0/90374400.0 [00:02<03:54, 381300.51it/s]WARNING: ParticleSet is empty on writing as array at time 777600
#   1%|          | 820800.0/90374400.0 [00:02<04:01, 370989.08it/s]WARNING: ParticleSet is empty on writing as array at time 820800
#   1%|          | 864000.0/90374400.0 [00:02<04:13, 353457.04it/s]WARNING: ParticleSet is empty on writing as array at time 864000
#   1%|          | 907200.0/90374400.0 [00:03<04:28, 332929.02it/s]WARNING: ParticleSet is empty on writing as array at time 907200
#   1%|          | 950400.0/90374400.0 [00:03<04:27, 334339.24it/s]WARNING: ParticleSet is empty on writing as array at time 950400
#   1%|          | 993600.0/90374400.0 [00:03<04:29, 331576.71it/s]WARNING: ParticleSet is empty on writing as array at time 993600
#   1%|          | 1036800.0/90374400.0 [00:03<04:34, 325705.42it/s]WARNING: ParticleSet is empty on writing as array at time 1.0368e+06
#   1%|          | 1080000.0/90374400.0 [00:03<04:28, 332538.19it/s]WARNING: ParticleSet is empty on writing as array at time 1.08e+06
#   1%|          | 1123200.0/90374400.0 [00:03<04:33, 326022.52it/s]WARNING: ParticleSet is empty on writing as array at time 1.1232e+06
#   1%|▏         | 1166400.0/90374400.0 [00:03<04:27, 332983.50it/s]WARNING: ParticleSet is empty on writing as array at time 1.1664e+06
#   1%|▏         | 1209600.0/90374400.0 [00:03<04:25, 335417.89it/s]WARNING: ParticleSet is empty on writing as array at time 1.2096e+06
# WARNING: ParticleSet is empty on writing as array at time 1.2528e+06
#   1%|▏         | 1296000.0/90374400.0 [00:04<04:08, 359067.19it/s]WARNING: ParticleSet is empty on writing as array at time 1.296e+06
#   1%|▏         | 1339200.0/90374400.0 [00:04<03:59, 371184.39it/s]WARNING: ParticleSet is empty on writing as array at time 1.3392e+06
#   2%|▏         | 1382400.0/90374400.0 [00:04<03:52, 382320.85it/s]WARNING: ParticleSet is empty on writing as array at time 1.3824e+06
#   2%|▏         | 1425600.0/90374400.0 [00:04<03:56, 375853.02it/s]WARNING: ParticleSet is empty on writing as array at time 1.4256e+06
#   2%|▏         | 1468800.0/90374400.0 [00:04<04:42, 314296.25it/s]WARNING: ParticleSet is empty on writing as array at time 1.4688e+06
#   2%|▏         | 1512000.0/90374400.0 [00:04<04:31, 327629.80it/s]WARNING: ParticleSet is empty on writing as array at time 1.512e+06
# WARNING: ParticleSet is empty on writing as array at time 1.5552e+06
#   2%|▏         | 1598400.0/90374400.0 [00:05<04:15, 347114.71it/s]WARNING: ParticleSet is empty on writing as array at time 1.5984e+06
#   2%|▏         | 1641600.0/90374400.0 [00:05<04:10, 354077.84it/s]WARNING: ParticleSet is empty on writing as array at time 1.6416e+06
#   2%|▏         | 1684800.0/90374400.0 [00:05<04:19, 341320.91it/s]WARNING: ParticleSet is empty on writing as array at time 1.6848e+06
#   2%|▏         | 1728000.0/90374400.0 [00:05<04:12, 350417.71it/s]WARNING: ParticleSet is empty on writing as array at time 1.728e+06
#   2%|▏         | 1771200.0/90374400.0 [00:05<04:19, 341215.41it/s]WARNING: ParticleSet is empty on writing as array at time 1.7712e+06
#   2%|▏         | 1814400.0/90374400.0 [00:05<04:13, 349493.18it/s]WARNING: ParticleSet is empty on writing as array at time 1.8144e+06
#   2%|▏         | 1857600.0/90374400.0 [00:05<04:10, 353761.30it/s]WARNING: ParticleSet is empty on writing as array at time 1.8576e+06
#   2%|▏         | 1900800.0/90374400.0 [00:05<04:21, 338173.60it/s]WARNING: ParticleSet is empty on writing as array at time 1.9008e+06
#   2%|▏         | 1944000.0/90374400.0 [00:06<04:25, 332728.58it/s]WARNING: ParticleSet is empty on writing as array at time 1.944e+06
#   2%|▏         | 1987200.0/90374400.0 [00:06<04:24, 333542.18it/s]WARNING: ParticleSet is empty on writing as array at time 1.9872e+06
#   2%|▏         | 2030400.0/90374400.0 [00:06<04:16, 344953.37it/s]WARNING: ParticleSet is empty on writing as array at time 2.0304e+06
# WARNING: ParticleSet is empty on writing as array at time 2.0736e+06
#   2%|▏         | 2116800.0/90374400.0 [00:06<04:10, 351988.05it/s]WARNING: ParticleSet is empty on writing as array at time 2.1168e+06
#   2%|▏         | 2160000.0/90374400.0 [00:06<04:17, 342451.81it/s]WARNING: ParticleSet is empty on writing as array at time 2.16e+06
# WARNING: ParticleSet is empty on writing as array at time 2.2032e+06
#   2%|▏         | 2246400.0/90374400.0 [00:06<04:03, 361287.70it/s]WARNING: ParticleSet is empty on writing as array at time 2.2464e+06
#   3%|▎         | 2289600.0/90374400.0 [00:07<04:24, 333277.20it/s]WARNING: ParticleSet is empty on writing as array at time 2.2896e+06
#   3%|▎         | 2332800.0/90374400.0 [00:07<04:18, 341231.16it/s]WARNING: ParticleSet is empty on writing as array at time 2.3328e+06
#   3%|▎         | 2376000.0/90374400.0 [00:07<04:12, 349108.33it/s]WARNING: ParticleSet is empty on writing as array at time 2.376e+06
# WARNING: ParticleSet is empty on writing as array at time 2.4192e+06
#   3%|▎         | 2462400.0/90374400.0 [00:07<03:58, 368717.17it/s]WARNING: ParticleSet is empty on writing as array at time 2.4624e+06
#   3%|▎         | 2505600.0/90374400.0 [00:07<04:01, 364114.77it/s]WARNING: ParticleSet is empty on writing as array at time 2.5056e+06
#   3%|▎         | 2548800.0/90374400.0 [00:07<04:00, 364906.49it/s]WARNING: ParticleSet is empty on writing as array at time 2.5488e+06
#   3%|▎         | 2592000.0/90374400.0 [00:07<04:01, 363349.94it/s]WARNING: ParticleSet is empty on writing as array at time 2.592e+06
#   3%|▎         | 2635200.0/90374400.0 [00:07<03:58, 367644.34it/s]WARNING: ParticleSet is empty on writing as array at time 2.6352e+06
#   3%|▎         | 2678400.0/90374400.0 [00:08<03:52, 377721.72it/s]WARNING: ParticleSet is empty on writing as array at time 2.6784e+06
#   3%|▎         | 2721600.0/90374400.0 [00:08<03:52, 377275.99it/s]WARNING: ParticleSet is empty on writing as array at time 2.7216e+06
#   3%|▎         | 2764800.0/90374400.0 [00:08<04:31, 322663.80it/s]WARNING: ParticleSet is empty on writing as array at time 2.7648e+06
#   3%|▎         | 2808000.0/90374400.0 [00:08<05:26, 267843.00it/s]WARNING: ParticleSet is empty on writing as array at time 2.808e+06
# WARNING: ParticleSet is empty on writing as array at time 2.8512e+06
#   3%|▎         | 2894400.0/90374400.0 [00:08<04:28, 325342.60it/s]WARNING: ParticleSet is empty on writing as array at time 2.8944e+06
#   3%|▎         | 2937600.0/90374400.0 [00:08<04:14, 343057.30it/s]WARNING: ParticleSet is empty on writing as array at time 2.9376e+06
#   3%|▎         | 2980800.0/90374400.0 [00:09<04:01, 361358.61it/s]WARNING: ParticleSet is empty on writing as array at time 2.9808e+06
#   3%|▎         | 3024000.0/90374400.0 [00:09<03:57, 367140.65it/s]WARNING: ParticleSet is empty on writing as array at time 3.024e+06
#   3%|▎         | 3067200.0/90374400.0 [00:09<03:58, 365557.74it/s]WARNING: ParticleSet is empty on writing as array at time 3.0672e+06
# WARNING: ParticleSet is empty on writing as array at time 3.1104e+06
#   3%|▎         | 3153600.0/90374400.0 [00:09<03:46, 384347.18it/s]WARNING: ParticleSet is empty on writing as array at time 3.1536e+06
# WARNING: ParticleSet is empty on writing as array at time 3.1968e+06
#   4%|▎         | 3240000.0/90374400.0 [00:09<03:30, 413484.23it/s]WARNING: ParticleSet is empty on writing as array at time 3.24e+06
# WARNING: ParticleSet is empty on writing as array at time 3.2832e+06
#   4%|▎         | 3326400.0/90374400.0 [00:09<03:19, 437283.01it/s]WARNING: ParticleSet is empty on writing as array at time 3.3264e+06
# WARNING: ParticleSet is empty on writing as array at time 3.3696e+06
#   4%|▍         | 3412800.0/90374400.0 [00:10<03:18, 437936.02it/s]WARNING: ParticleSet is empty on writing as array at time 3.4128e+06
# WARNING: ParticleSet is empty on writing as array at time 3.456e+06
#   4%|▍         | 3499200.0/90374400.0 [00:10<03:18, 437057.55it/s]WARNING: ParticleSet is empty on writing as array at time 3.4992e+06
# WARNING: ParticleSet is empty on writing as array at time 3.5424e+06
#   4%|▍         | 3585600.0/90374400.0 [00:10<03:29, 414021.90it/s]WARNING: ParticleSet is empty on writing as array at time 3.5856e+06
#   4%|▍         | 3628800.0/90374400.0 [00:10<03:29, 414569.36it/s]WARNING: ParticleSet is empty on writing as array at time 3.6288e+06
#   4%|▍         | 3672000.0/90374400.0 [00:10<03:28, 415862.04it/s]WARNING: ParticleSet is empty on writing as array at time 3.672e+06
#   4%|▍         | 3715200.0/90374400.0 [00:10<03:36, 400291.39it/s]WARNING: ParticleSet is empty on writing as array at time 3.7152e+06
#   4%|▍         | 3758400.0/90374400.0 [00:10<03:41, 390432.45it/s]WARNING: ParticleSet is empty on writing as array at time 3.7584e+06
#   4%|▍         | 3801600.0/90374400.0 [00:11<03:58, 363725.12it/s]WARNING: ParticleSet is empty on writing as array at time 3.8016e+06
#   4%|▍         | 3844800.0/90374400.0 [00:11<03:50, 375877.67it/s]WARNING: ParticleSet is empty on writing as array at time 3.8448e+06
#   4%|▍         | 3888000.0/90374400.0 [00:11<03:44, 385261.65it/s]WARNING: ParticleSet is empty on writing as array at time 3.888e+06
#   4%|▍         | 3931200.0/90374400.0 [00:11<03:47, 380503.11it/s]WARNING: ParticleSet is empty on writing as array at time 3.9312e+06
#   4%|▍         | 3974400.0/90374400.0 [00:11<03:56, 365975.17it/s]WARNING: ParticleSet is empty on writing as array at time 3.9744e+06
#   4%|▍         | 4017600.0/90374400.0 [00:11<03:54, 367852.83it/s]WARNING: ParticleSet is empty on writing as array at time 4.0176e+06
# WARNING: ParticleSet is empty on writing as array at time 4.0608e+06
#   5%|▍         | 4104000.0/90374400.0 [00:11<03:42, 387175.81it/s]WARNING: ParticleSet is empty on writing as array at time 4.104e+06
#   5%|▍         | 4147200.0/90374400.0 [00:11<03:41, 389902.71it/s]WARNING: ParticleSet is empty on writing as array at time 4.1472e+06
#   5%|▍         | 4190400.0/90374400.0 [00:12<03:42, 387360.13it/s]WARNING: ParticleSet is empty on writing as array at time 4.1904e+06
#   5%|▍         | 4233600.0/90374400.0 [00:12<04:06, 349205.97it/s]WARNING: ParticleSet is empty on writing as array at time 4.2336e+06
#   5%|▍         | 4276800.0/90374400.0 [00:12<04:53, 293254.12it/s]WARNING: ParticleSet is empty on writing as array at time 4.2768e+06
#   5%|▍         | 4320000.0/90374400.0 [00:12<04:33, 314548.10it/s]WARNING: ParticleSet is empty on writing as array at time 4.32e+06
#   5%|▍         | 4363200.0/90374400.0 [00:12<04:22, 327930.91it/s]WARNING: ParticleSet is empty on writing as array at time 4.3632e+06
#   5%|▍         | 4406400.0/90374400.0 [00:12<04:15, 336794.26it/s]WARNING: ParticleSet is empty on writing as array at time 4.4064e+06
#   5%|▍         | 4449600.0/90374400.0 [00:12<04:07, 346648.98it/s]WARNING: ParticleSet is empty on writing as array at time 4.4496e+06
#   5%|▍         | 4492800.0/90374400.0 [00:13<04:44, 302175.27it/s]WARNING: ParticleSet is empty on writing as array at time 4.4928e+06
# WARNING: ParticleSet is empty on writing as array at time 4.536e+06
#   5%|▌         | 4579200.0/90374400.0 [00:13<03:55, 363838.28it/s]WARNING: ParticleSet is empty on writing as array at time 4.5792e+06
# WARNING: ParticleSet is empty on writing as array at time 4.6224e+06
#   5%|▌         | 4665600.0/90374400.0 [00:13<03:39, 389959.46it/s]WARNING: ParticleSet is empty on writing as array at time 4.6656e+06
# WARNING: ParticleSet is empty on writing as array at time 4.7088e+06
#   5%|▌         | 4752000.0/90374400.0 [00:13<03:24, 418801.31it/s]WARNING: ParticleSet is empty on writing as array at time 4.752e+06
# WARNING: ParticleSet is empty on writing as array at time 4.7952e+06
#   5%|▌         | 4838400.0/90374400.0 [00:13<03:23, 419594.26it/s]WARNING: ParticleSet is empty on writing as array at time 4.8384e+06
#   5%|▌         | 4881600.0/90374400.0 [00:14<04:02, 352438.85it/s]WARNING: ParticleSet is empty on writing as array at time 4.8816e+06
#   5%|▌         | 4924800.0/90374400.0 [00:14<03:53, 365959.07it/s]WARNING: ParticleSet is empty on writing as array at time 4.9248e+06
#   5%|▌         | 4968000.0/90374400.0 [00:14<03:47, 375016.04it/s]WARNING: ParticleSet is empty on writing as array at time 4.968e+06
#   6%|▌         | 5011200.0/90374400.0 [00:14<03:42, 384066.60it/s]WARNING: ParticleSet is empty on writing as array at time 5.0112e+06
#   6%|▌         | 5054400.0/90374400.0 [00:14<03:38, 389758.24it/s]WARNING: ParticleSet is empty on writing as array at time 5.0544e+06
# WARNING: ParticleSet is empty on writing as array at time 5.0976e+06
#   6%|▌         | 5140800.0/90374400.0 [00:14<03:24, 416912.75it/s]WARNING: ParticleSet is empty on writing as array at time 5.1408e+06
#   6%|▌         | 5184000.0/90374400.0 [00:14<03:23, 419183.72it/s]WARNING: ParticleSet is empty on writing as array at time 5.184e+06
# WARNING: ParticleSet is empty on writing as array at time 5.2272e+06
#   6%|▌         | 5270400.0/90374400.0 [00:14<03:04, 462459.46it/s]WARNING: ParticleSet is empty on writing as array at time 5.2704e+06
# WARNING: ParticleSet is empty on writing as array at time 5.3136e+06
#   6%|▌         | 5356800.0/90374400.0 [00:15<03:18, 429333.35it/s]WARNING: ParticleSet is empty on writing as array at time 5.3568e+06
# WARNING: ParticleSet is empty on writing as array at time 5.4e+06
#   6%|▌         | 5443200.0/90374400.0 [00:15<03:00, 470619.67it/s]WARNING: ParticleSet is empty on writing as array at time 5.4432e+06
# WARNING: ParticleSet is empty on writing as array at time 5.4864e+06
#   6%|▌         | 5529600.0/90374400.0 [00:15<02:53, 488764.19it/s]WARNING: ParticleSet is empty on writing as array at time 5.5296e+06
# WARNING: ParticleSet is empty on writing as array at time 5.5728e+06
#   6%|▌         | 5616000.0/90374400.0 [00:15<03:11, 442730.52it/s]WARNING: ParticleSet is empty on writing as array at time 5.616e+06
# WARNING: ParticleSet is empty on writing as array at time 5.6592e+06
#   6%|▋         | 5702400.0/90374400.0 [00:15<03:24, 414734.87it/s]WARNING: ParticleSet is empty on writing as array at time 5.7024e+06
#   6%|▋         | 5745600.0/90374400.0 [00:16<03:33, 396311.29it/s]WARNING: ParticleSet is empty on writing as array at time 5.7456e+06
#   6%|▋         | 5788800.0/90374400.0 [00:16<03:36, 390513.44it/s]WARNING: ParticleSet is empty on writing as array at time 5.7888e+06
#   6%|▋         | 5832000.0/90374400.0 [00:16<03:41, 380945.09it/s]WARNING: ParticleSet is empty on writing as array at time 5.832e+06
#   7%|▋         | 5875200.0/90374400.0 [00:16<03:47, 371778.07it/s]WARNING: ParticleSet is empty on writing as array at time 5.8752e+06
#   7%|▋         | 5918400.0/90374400.0 [00:16<03:40, 383731.14it/s]WARNING: ParticleSet is empty on writing as array at time 5.9184e+06
# WARNING: ParticleSet is empty on writing as array at time 5.9616e+06
#   7%|▋         | 6004800.0/90374400.0 [00:16<03:22, 417291.81it/s]WARNING: ParticleSet is empty on writing as array at time 6.0048e+06
#   7%|▋         | 6048000.0/90374400.0 [00:16<03:27, 407360.96it/s]WARNING: ParticleSet is empty on writing as array at time 6.048e+06
#   7%|▋         | 6091200.0/90374400.0 [00:16<03:25, 409607.40it/s]WARNING: ParticleSet is empty on writing as array at time 6.0912e+06
# WARNING: ParticleSet is empty on writing as array at time 6.1344e+06
#   7%|▋         | 6177600.0/90374400.0 [00:17<03:13, 434919.37it/s]WARNING: ParticleSet is empty on writing as array at time 6.1776e+06
# WARNING: ParticleSet is empty on writing as array at time 6.2208e+06
#   7%|▋         | 6264000.0/90374400.0 [00:17<03:06, 451665.18it/s]WARNING: ParticleSet is empty on writing as array at time 6.264e+06
# WARNING: ParticleSet is empty on writing as array at time 6.3072e+06
#   7%|▋         | 6350400.0/90374400.0 [00:17<02:58, 470654.91it/s]WARNING: ParticleSet is empty on writing as array at time 6.3504e+06
# WARNING: ParticleSet is empty on writing as array at time 6.3936e+06
#   7%|▋         | 6436800.0/90374400.0 [00:17<03:34, 390897.54it/s]WARNING: ParticleSet is empty on writing as array at time 6.4368e+06
# WARNING: ParticleSet is empty on writing as array at time 6.48e+06
#   7%|▋         | 6523200.0/90374400.0 [00:17<03:22, 413134.82it/s]WARNING: ParticleSet is empty on writing as array at time 6.5232e+06
# WARNING: ParticleSet is empty on writing as array at time 6.5664e+06
#   7%|▋         | 6609600.0/90374400.0 [00:18<03:08, 445049.95it/s]WARNING: ParticleSet is empty on writing as array at time 6.6096e+06
# WARNING: ParticleSet is empty on writing as array at time 6.6528e+06
#   7%|▋         | 6696000.0/90374400.0 [00:18<03:08, 443572.32it/s]WARNING: ParticleSet is empty on writing as array at time 6.696e+06
# WARNING: ParticleSet is empty on writing as array at time 6.7392e+06
#   8%|▊         | 6782400.0/90374400.0 [00:18<03:02, 457031.74it/s]WARNING: ParticleSet is empty on writing as array at time 6.7824e+06
# WARNING: ParticleSet is empty on writing as array at time 6.8256e+06
#   8%|▊         | 6868800.0/90374400.0 [00:18<03:04, 452513.73it/s]WARNING: ParticleSet is empty on writing as array at time 6.8688e+06
# WARNING: ParticleSet is empty on writing as array at time 6.912e+06
#   8%|▊         | 6955200.0/90374400.0 [00:18<03:06, 447008.73it/s]WARNING: ParticleSet is empty on writing as array at time 6.9552e+06
# WARNING: ParticleSet is empty on writing as array at time 6.9984e+06
#   8%|▊         | 7041600.0/90374400.0 [00:19<03:00, 461317.00it/s]WARNING: ParticleSet is empty on writing as array at time 7.0416e+06
# WARNING: ParticleSet is empty on writing as array at time 7.0848e+06
#   8%|▊         | 7128000.0/90374400.0 [00:19<02:55, 475409.99it/s]WARNING: ParticleSet is empty on writing as array at time 7.128e+06
# WARNING: ParticleSet is empty on writing as array at time 7.1712e+06
#   8%|▊         | 7214400.0/90374400.0 [00:19<02:50, 487442.20it/s]WARNING: ParticleSet is empty on writing as array at time 7.2144e+06
# WARNING: ParticleSet is empty on writing as array at time 7.2576e+06
#   8%|▊         | 7300800.0/90374400.0 [00:19<02:51, 483489.06it/s]WARNING: ParticleSet is empty on writing as array at time 7.3008e+06
# WARNING: ParticleSet is empty on writing as array at time 7.344e+06
#   8%|▊         | 7387200.0/90374400.0 [00:19<02:53, 477479.49it/s]WARNING: ParticleSet is empty on writing as array at time 7.3872e+06
# WARNING: ParticleSet is empty on writing as array at time 7.4304e+06
#   8%|▊         | 7473600.0/90374400.0 [00:19<03:05, 446560.87it/s]WARNING: ParticleSet is empty on writing as array at time 7.4736e+06
# WARNING: ParticleSet is empty on writing as array at time 7.5168e+06
#   8%|▊         | 7560000.0/90374400.0 [00:20<02:56, 469708.20it/s]WARNING: ParticleSet is empty on writing as array at time 7.56e+06
# WARNING: ParticleSet is empty on writing as array at time 7.6032e+06
#   8%|▊         | 7646400.0/90374400.0 [00:20<02:53, 477278.97it/s]WARNING: ParticleSet is empty on writing as array at time 7.6464e+06
# WARNING: ParticleSet is empty on writing as array at time 7.6896e+06
#   9%|▊         | 7732800.0/90374400.0 [00:20<03:06, 442816.38it/s]WARNING: ParticleSet is empty on writing as array at time 7.7328e+06
# WARNING: ParticleSet is empty on writing as array at time 7.776e+06
#   9%|▊         | 7819200.0/90374400.0 [00:20<02:59, 460335.17it/s]WARNING: ParticleSet is empty on writing as array at time 7.8192e+06
# WARNING: ParticleSet is empty on writing as array at time 7.8624e+06
#   9%|▊         | 7905600.0/90374400.0 [00:20<02:56, 468400.03it/s]WARNING: ParticleSet is empty on writing as array at time 7.9056e+06
# WARNING: ParticleSet is empty on writing as array at time 7.9488e+06
#   9%|▉         | 7992000.0/90374400.0 [00:21<02:53, 475008.46it/s]WARNING: ParticleSet is empty on writing as array at time 7.992e+06
# WARNING: ParticleSet is empty on writing as array at time 8.0352e+06
#   9%|▉         | 8078400.0/90374400.0 [00:21<02:46, 494571.59it/s]WARNING: ParticleSet is empty on writing as array at time 8.0784e+06
# WARNING: ParticleSet is empty on writing as array at time 8.1216e+06
#   9%|▉         | 8164800.0/90374400.0 [00:21<02:49, 486227.89it/s]WARNING: ParticleSet is empty on writing as array at time 8.1648e+06
# WARNING: ParticleSet is empty on writing as array at time 8.208e+06
#   9%|▉         | 8251200.0/90374400.0 [00:21<02:42, 506098.39it/s]WARNING: ParticleSet is empty on writing as array at time 8.2512e+06
# WARNING: ParticleSet is empty on writing as array at time 8.2944e+06
#   9%|▉         | 8337600.0/90374400.0 [00:21<02:38, 518223.10it/s]WARNING: ParticleSet is empty on writing as array at time 8.3376e+06
# WARNING: ParticleSet is empty on writing as array at time 8.3808e+06
#   9%|▉         | 8424000.0/90374400.0 [00:21<02:44, 499573.77it/s]WARNING: ParticleSet is empty on writing as array at time 8.424e+06
# WARNING: ParticleSet is empty on writing as array at time 8.4672e+06
#   9%|▉         | 8510400.0/90374400.0 [00:22<03:02, 449779.40it/s]WARNING: ParticleSet is empty on writing as array at time 8.5104e+06
# WARNING: ParticleSet is empty on writing as array at time 8.5536e+06
#  10%|▉         | 8596800.0/90374400.0 [00:22<03:02, 447266.03it/s]WARNING: ParticleSet is empty on writing as array at time 8.5968e+06
# WARNING: ParticleSet is empty on writing as array at time 8.64e+06
#  10%|▉         | 8683200.0/90374400.0 [00:22<02:56, 461870.47it/s]WARNING: ParticleSet is empty on writing as array at time 8.6832e+06
# WARNING: ParticleSet is empty on writing as array at time 8.7264e+06
#  10%|▉         | 8769600.0/90374400.0 [00:22<02:48, 484796.01it/s]WARNING: ParticleSet is empty on writing as array at time 8.7696e+06
# WARNING: ParticleSet is empty on writing as array at time 8.8128e+06
#  10%|▉         | 8856000.0/90374400.0 [00:22<02:50, 476880.12it/s]WARNING: ParticleSet is empty on writing as array at time 8.856e+06
# WARNING: ParticleSet is empty on writing as array at time 8.8992e+06
#  10%|▉         | 8942400.0/90374400.0 [00:23<02:55, 464679.57it/s]WARNING: ParticleSet is empty on writing as array at time 8.9424e+06
# WARNING: ParticleSet is empty on writing as array at time 8.9856e+06
#  10%|▉         | 9028800.0/90374400.0 [00:23<03:02, 446485.25it/s]WARNING: ParticleSet is empty on writing as array at time 9.0288e+06
# WARNING: ParticleSet is empty on writing as array at time 9.072e+06
#  10%|█         | 9115200.0/90374400.0 [00:23<03:15, 415956.67it/s]WARNING: ParticleSet is empty on writing as array at time 9.1152e+06
# WARNING: ParticleSet is empty on writing as array at time 9.1584e+06
#  10%|█         | 9201600.0/90374400.0 [00:23<03:37, 372646.52it/s]WARNING: ParticleSet is empty on writing as array at time 9.2016e+06
#  10%|█         | 9244800.0/90374400.0 [00:23<03:34, 378917.14it/s]WARNING: ParticleSet is empty on writing as array at time 9.2448e+06
#  10%|█         | 9288000.0/90374400.0 [00:23<03:31, 383151.78it/s]WARNING: ParticleSet is empty on writing as array at time 9.288e+06
#  10%|█         | 9331200.0/90374400.0 [00:24<03:36, 374673.84it/s]WARNING: ParticleSet is empty on writing as array at time 9.3312e+06
#  10%|█         | 9374400.0/90374400.0 [00:24<03:36, 374468.61it/s]WARNING: ParticleSet is empty on writing as array at time 9.3744e+06
#  10%|█         | 9417600.0/90374400.0 [00:24<03:31, 383497.92it/s]WARNING: ParticleSet is empty on writing as array at time 9.4176e+06
#  10%|█         | 9460800.0/90374400.0 [00:24<03:48, 354770.21it/s]WARNING: ParticleSet is empty on writing as array at time 9.4608e+06
#  11%|█         | 9504000.0/90374400.0 [00:24<03:46, 357250.30it/s]WARNING: ParticleSet is empty on writing as array at time 9.504e+06
# WARNING: ParticleSet is empty on writing as array at time 9.5472e+06
#  11%|█         | 9590400.0/90374400.0 [00:24<03:28, 387014.46it/s]WARNING: ParticleSet is empty on writing as array at time 9.5904e+06
#  11%|█         | 9633600.0/90374400.0 [00:24<03:28, 386652.82it/s]WARNING: ParticleSet is empty on writing as array at time 9.6336e+06
# WARNING: ParticleSet is empty on writing as array at time 9.6768e+06
#  11%|█         | 9720000.0/90374400.0 [00:25<03:05, 433636.61it/s]WARNING: ParticleSet is empty on writing as array at time 9.72e+06
# WARNING: ParticleSet is empty on writing as array at time 9.7632e+06
#  11%|█         | 9806400.0/90374400.0 [00:25<02:48, 479123.46it/s]WARNING: ParticleSet is empty on writing as array at time 9.8064e+06
# WARNING: ParticleSet is empty on writing as array at time 9.8496e+06
#  11%|█         | 9892800.0/90374400.0 [00:25<02:53, 464935.72it/s]WARNING: ParticleSet is empty on writing as array at time 9.8928e+06
# WARNING: ParticleSet is empty on writing as array at time 9.936e+06
#  11%|█         | 9979200.0/90374400.0 [00:25<03:01, 442053.51it/s]WARNING: ParticleSet is empty on writing as array at time 9.9792e+06
# WARNING: ParticleSet is empty on writing as array at time 1.00224e+07
#  11%|█         | 10065600.0/90374400.0 [00:25<03:04, 435870.01it/s]WARNING: ParticleSet is empty on writing as array at time 1.00656e+07
# WARNING: ParticleSet is empty on writing as array at time 1.01088e+07
#  11%|█         | 10152000.0/90374400.0 [00:25<02:50, 471849.78it/s]WARNING: ParticleSet is empty on writing as array at time 1.0152e+07
# WARNING: ParticleSet is empty on writing as array at time 1.01952e+07
#  11%|█▏        | 10238400.0/90374400.0 [00:26<02:54, 458023.27it/s]WARNING: ParticleSet is empty on writing as array at time 1.02384e+07
# WARNING: ParticleSet is empty on writing as array at time 1.02816e+07
#  11%|█▏        | 10324800.0/90374400.0 [00:26<03:00, 442622.86it/s]WARNING: ParticleSet is empty on writing as array at time 1.03248e+07
# WARNING: ParticleSet is empty on writing as array at time 1.0368e+07
#  12%|█▏        | 10411200.0/90374400.0 [00:26<03:07, 426207.86it/s]WARNING: ParticleSet is empty on writing as array at time 1.04112e+07
# WARNING: ParticleSet is empty on writing as array at time 1.04544e+07
#  12%|█▏        | 10497600.0/90374400.0 [00:26<02:58, 446862.15it/s]WARNING: ParticleSet is empty on writing as array at time 1.04976e+07
# WARNING: ParticleSet is empty on writing as array at time 1.05408e+07
#  12%|█▏        | 10584000.0/90374400.0 [00:27<03:08, 423063.18it/s]WARNING: ParticleSet is empty on writing as array at time 1.0584e+07
#  12%|█▏        | 10627200.0/90374400.0 [00:27<03:10, 418895.44it/s]WARNING: ParticleSet is empty on writing as array at time 1.06272e+07
# WARNING: ParticleSet is empty on writing as array at time 1.06704e+07
#  12%|█▏        | 10713600.0/90374400.0 [00:27<03:08, 422970.83it/s]WARNING: ParticleSet is empty on writing as array at time 1.07136e+07
#  12%|█▏        | 10756800.0/90374400.0 [00:27<03:08, 422091.26it/s]WARNING: ParticleSet is empty on writing as array at time 1.07568e+07
# WARNING: ParticleSet is empty on writing as array at time 1.08e+07
#  12%|█▏        | 10843200.0/90374400.0 [00:27<02:56, 451209.20it/s]WARNING: ParticleSet is empty on writing as array at time 1.08432e+07
# WARNING: ParticleSet is empty on writing as array at time 1.08864e+07
#  12%|█▏        | 10929600.0/90374400.0 [00:27<02:45, 480384.39it/s]WARNING: ParticleSet is empty on writing as array at time 1.09296e+07
# WARNING: ParticleSet is empty on writing as array at time 1.09728e+07
#  12%|█▏        | 11016000.0/90374400.0 [00:27<02:47, 473269.58it/s]WARNING: ParticleSet is empty on writing as array at time 1.1016e+07
# WARNING: ParticleSet is empty on writing as array at time 1.10592e+07
#  12%|█▏        | 11102400.0/90374400.0 [00:28<02:48, 469117.28it/s]WARNING: ParticleSet is empty on writing as array at time 1.11024e+07
# WARNING: ParticleSet is empty on writing as array at time 1.11456e+07
#  12%|█▏        | 11188800.0/90374400.0 [00:28<02:50, 464209.31it/s]WARNING: ParticleSet is empty on writing as array at time 1.11888e+07
# WARNING: ParticleSet is empty on writing as array at time 1.1232e+07
#  12%|█▏        | 11275200.0/90374400.0 [00:28<02:56, 448864.74it/s]WARNING: ParticleSet is empty on writing as array at time 1.12752e+07
# WARNING: ParticleSet is empty on writing as array at time 1.13184e+07
#  13%|█▎        | 11361600.0/90374400.0 [00:28<02:52, 457846.26it/s]WARNING: ParticleSet is empty on writing as array at time 1.13616e+07
# WARNING: ParticleSet is empty on writing as array at time 1.14048e+07
#  13%|█▎        | 11448000.0/90374400.0 [00:28<03:00, 436254.06it/s]WARNING: ParticleSet is empty on writing as array at time 1.1448e+07
# WARNING: ParticleSet is empty on writing as array at time 1.14912e+07
#  13%|█▎        | 11534400.0/90374400.0 [00:29<02:51, 460250.05it/s]WARNING: ParticleSet is empty on writing as array at time 1.15344e+07
# WARNING: ParticleSet is empty on writing as array at time 1.15776e+07
#  13%|█▎        | 11620800.0/90374400.0 [00:29<02:51, 460039.37it/s]WARNING: ParticleSet is empty on writing as array at time 1.16208e+07
# WARNING: ParticleSet is empty on writing as array at time 1.1664e+07
#  13%|█▎        | 11707200.0/90374400.0 [00:29<02:48, 467132.44it/s]WARNING: ParticleSet is empty on writing as array at time 1.17072e+07
# WARNING: ParticleSet is empty on writing as array at time 1.17504e+07
#  13%|█▎        | 11793600.0/90374400.0 [00:29<02:44, 477973.69it/s]WARNING: ParticleSet is empty on writing as array at time 1.17936e+07
# WARNING: ParticleSet is empty on writing as array at time 1.18368e+07
#  13%|█▎        | 11880000.0/90374400.0 [00:29<02:50, 460889.85it/s]WARNING: ParticleSet is empty on writing as array at time 1.188e+07
# WARNING: ParticleSet is empty on writing as array at time 1.19232e+07
#  13%|█▎        | 11966400.0/90374400.0 [00:30<02:52, 455419.35it/s]WARNING: ParticleSet is empty on writing as array at time 1.19664e+07
# WARNING: ParticleSet is empty on writing as array at time 1.20096e+07
#  13%|█▎        | 12052800.0/90374400.0 [00:30<03:17, 396811.39it/s]WARNING: ParticleSet is empty on writing as array at time 1.20528e+07
# WARNING: ParticleSet is empty on writing as array at time 1.2096e+07
#  13%|█▎        | 12139200.0/90374400.0 [00:30<03:14, 402753.05it/s]WARNING: ParticleSet is empty on writing as array at time 1.21392e+07
# WARNING: ParticleSet is empty on writing as array at time 1.21824e+07
#  14%|█▎        | 12225600.0/90374400.0 [00:30<03:11, 408116.43it/s]WARNING: ParticleSet is empty on writing as array at time 1.22256e+07
#  14%|█▎        | 12268800.0/90374400.0 [00:30<03:09, 411497.40it/s]WARNING: ParticleSet is empty on writing as array at time 1.22688e+07
#  14%|█▎        | 12312000.0/90374400.0 [00:30<03:10, 409668.36it/s]WARNING: ParticleSet is empty on writing as array at time 1.2312e+07
# WARNING: ParticleSet is empty on writing as array at time 1.23552e+07
#  14%|█▎        | 12398400.0/90374400.0 [00:31<02:53, 449202.43it/s]WARNING: ParticleSet is empty on writing as array at time 1.23984e+07
# WARNING: ParticleSet is empty on writing as array at time 1.24416e+07
#  14%|█▍        | 12484800.0/90374400.0 [00:31<02:39, 489282.10it/s]WARNING: ParticleSet is empty on writing as array at time 1.24848e+07
# WARNING: ParticleSet is empty on writing as array at time 1.2528e+07
#  14%|█▍        | 12571200.0/90374400.0 [00:31<02:41, 481579.43it/s]WARNING: ParticleSet is empty on writing as array at time 1.25712e+07
# WARNING: ParticleSet is empty on writing as array at time 1.26144e+07
#  14%|█▍        | 12657600.0/90374400.0 [00:31<02:29, 520699.96it/s]WARNING: ParticleSet is empty on writing as array at time 1.26576e+07
# WARNING: ParticleSet is empty on writing as array at time 1.27008e+07
#  14%|█▍        | 12744000.0/90374400.0 [00:31<02:24, 538986.66it/s]WARNING: ParticleSet is empty on writing as array at time 1.2744e+07
# WARNING: ParticleSet is empty on writing as array at time 1.27872e+07
#  14%|█▍        | 12830400.0/90374400.0 [00:31<02:21, 549905.62it/s]WARNING: ParticleSet is empty on writing as array at time 1.28304e+07
# WARNING: ParticleSet is empty on writing as array at time 1.28736e+07
#  14%|█▍        | 12916800.0/90374400.0 [00:31<02:14, 577817.55it/s]WARNING: ParticleSet is empty on writing as array at time 1.29168e+07
# WARNING: ParticleSet is empty on writing as array at time 1.296e+07
#  14%|█▍        | 13003200.0/90374400.0 [00:32<02:08, 603195.79it/s]WARNING: ParticleSet is empty on writing as array at time 1.30032e+07
# WARNING: ParticleSet is empty on writing as array at time 1.30464e+07
#  14%|█▍        | 13089600.0/90374400.0 [00:32<02:04, 619819.78it/s]WARNING: ParticleSet is empty on writing as array at time 1.30896e+07
# WARNING: ParticleSet is empty on writing as array at time 1.31328e+07
#  15%|█▍        | 13176000.0/90374400.0 [00:32<02:04, 621597.51it/s]WARNING: ParticleSet is empty on writing as array at time 1.3176e+07
# WARNING: ParticleSet is empty on writing as array at time 1.32192e+07
#  15%|█▍        | 13262400.0/90374400.0 [00:32<02:02, 628656.71it/s]WARNING: ParticleSet is empty on writing as array at time 1.32624e+07
# WARNING: ParticleSet is empty on writing as array at time 1.33056e+07
#  15%|█▍        | 13348800.0/90374400.0 [00:32<02:00, 639682.31it/s]WARNING: ParticleSet is empty on writing as array at time 1.33488e+07
# WARNING: ParticleSet is empty on writing as array at time 1.3392e+07
#  15%|█▍        | 13435200.0/90374400.0 [00:32<02:16, 561648.13it/s]WARNING: ParticleSet is empty on writing as array at time 1.34352e+07
# WARNING: ParticleSet is empty on writing as array at time 1.34784e+07
#  15%|█▍        | 13521600.0/90374400.0 [00:33<02:21, 542789.26it/s]WARNING: ParticleSet is empty on writing as array at time 1.35216e+07
# WARNING: ParticleSet is empty on writing as array at time 1.35648e+07
#  15%|█▌        | 13608000.0/90374400.0 [00:33<02:22, 539232.60it/s]WARNING: ParticleSet is empty on writing as array at time 1.3608e+07
# WARNING: ParticleSet is empty on writing as array at time 1.36512e+07
#  15%|█▌        | 13694400.0/90374400.0 [00:33<02:32, 502073.10it/s]WARNING: ParticleSet is empty on writing as array at time 1.36944e+07
# WARNING: ParticleSet is empty on writing as array at time 1.37376e+07
#  15%|█▌        | 13780800.0/90374400.0 [00:33<02:50, 450483.73it/s]WARNING: ParticleSet is empty on writing as array at time 1.37808e+07
# WARNING: ParticleSet is empty on writing as array at time 1.3824e+07
#  15%|█▌        | 13867200.0/90374400.0 [00:33<02:54, 439235.97it/s]WARNING: ParticleSet is empty on writing as array at time 1.38672e+07
# WARNING: ParticleSet is empty on writing as array at time 1.39104e+07
#  15%|█▌        | 13953600.0/90374400.0 [00:33<02:50, 446913.75it/s]WARNING: ParticleSet is empty on writing as array at time 1.39536e+07
# WARNING: ParticleSet is empty on writing as array at time 1.39968e+07
#  16%|█▌        | 14040000.0/90374400.0 [00:34<02:44, 464917.22it/s]WARNING: ParticleSet is empty on writing as array at time 1.404e+07
# WARNING: ParticleSet is empty on writing as array at time 1.40832e+07
#  16%|█▌        | 14126400.0/90374400.0 [00:34<02:42, 469805.34it/s]WARNING: ParticleSet is empty on writing as array at time 1.41264e+07
# WARNING: ParticleSet is empty on writing as array at time 1.41696e+07
#  16%|█▌        | 14212800.0/90374400.0 [00:34<02:59, 423500.68it/s]WARNING: ParticleSet is empty on writing as array at time 1.42128e+07
# WARNING: ParticleSet is empty on writing as array at time 1.4256e+07
#  16%|█▌        | 14299200.0/90374400.0 [00:34<02:55, 434130.81it/s]WARNING: ParticleSet is empty on writing as array at time 1.42992e+07
# WARNING: ParticleSet is empty on writing as array at time 1.43424e+07
#  16%|█▌        | 14385600.0/90374400.0 [00:34<02:51, 442695.73it/s]WARNING: ParticleSet is empty on writing as array at time 1.43856e+07
# WARNING: ParticleSet is empty on writing as array at time 1.44288e+07
#  16%|█▌        | 14472000.0/90374400.0 [00:35<02:57, 427221.56it/s]WARNING: ParticleSet is empty on writing as array at time 1.4472e+07
# WARNING: ParticleSet is empty on writing as array at time 1.45152e+07
#  16%|█▌        | 14558400.0/90374400.0 [00:35<03:09, 401124.37it/s]WARNING: ParticleSet is empty on writing as array at time 1.45584e+07
#  16%|█▌        | 14601600.0/90374400.0 [00:35<03:06, 405904.04it/s]WARNING: ParticleSet is empty on writing as array at time 1.46016e+07
# WARNING: ParticleSet is empty on writing as array at time 1.46448e+07
#  16%|█▋        | 14688000.0/90374400.0 [00:35<03:19, 379994.82it/s]WARNING: ParticleSet is empty on writing as array at time 1.4688e+07
#  16%|█▋        | 14731200.0/90374400.0 [00:35<03:31, 357371.73it/s]WARNING: ParticleSet is empty on writing as array at time 1.47312e+07
#  16%|█▋        | 14774400.0/90374400.0 [00:36<03:27, 364619.14it/s]WARNING: ParticleSet is empty on writing as array at time 1.47744e+07
# WARNING: ParticleSet is empty on writing as array at time 1.48176e+07
#  16%|█▋        | 14860800.0/90374400.0 [00:36<03:06, 404617.50it/s]WARNING: ParticleSet is empty on writing as array at time 1.48608e+07
# WARNING: ParticleSet is empty on writing as array at time 1.4904e+07
#  17%|█▋        | 14947200.0/90374400.0 [00:36<02:56, 428005.01it/s]WARNING: ParticleSet is empty on writing as array at time 1.49472e+07
# WARNING: ParticleSet is empty on writing as array at time 1.49904e+07
#  17%|█▋        | 15033600.0/90374400.0 [00:36<02:53, 435275.59it/s]WARNING: ParticleSet is empty on writing as array at time 1.50336e+07
# WARNING: ParticleSet is empty on writing as array at time 1.50768e+07
#  17%|█▋        | 15120000.0/90374400.0 [00:36<02:51, 439644.41it/s]WARNING: ParticleSet is empty on writing as array at time 1.512e+07
# WARNING: ParticleSet is empty on writing as array at time 1.51632e+07
#  17%|█▋        | 15206400.0/90374400.0 [00:36<02:44, 458221.41it/s]WARNING: ParticleSet is empty on writing as array at time 1.52064e+07
# WARNING: ParticleSet is empty on writing as array at time 1.52496e+07
#  17%|█▋        | 15292800.0/90374400.0 [00:37<02:37, 477607.39it/s]WARNING: ParticleSet is empty on writing as array at time 1.52928e+07
# WARNING: ParticleSet is empty on writing as array at time 1.5336e+07
#  17%|█▋        | 15379200.0/90374400.0 [00:37<02:36, 479318.46it/s]WARNING: ParticleSet is empty on writing as array at time 1.53792e+07
# WARNING: ParticleSet is empty on writing as array at time 1.54224e+07
#  17%|█▋        | 15465600.0/90374400.0 [00:37<02:32, 490252.98it/s]WARNING: ParticleSet is empty on writing as array at time 1.54656e+07
# WARNING: ParticleSet is empty on writing as array at time 1.55088e+07
#  17%|█▋        | 15552000.0/90374400.0 [00:37<02:35, 482597.09it/s]WARNING: ParticleSet is empty on writing as array at time 1.5552e+07
# WARNING: ParticleSet is empty on writing as array at time 1.55952e+07
#  17%|█▋        | 15638400.0/90374400.0 [00:37<02:39, 469464.06it/s]WARNING: ParticleSet is empty on writing as array at time 1.56384e+07
# WARNING: ParticleSet is empty on writing as array at time 1.56816e+07
#  17%|█▋        | 15724800.0/90374400.0 [00:38<02:40, 464223.89it/s]WARNING: ParticleSet is empty on writing as array at time 1.57248e+07
# WARNING: ParticleSet is empty on writing as array at time 1.5768e+07
#  17%|█▋        | 15811200.0/90374400.0 [00:38<02:45, 449310.61it/s]WARNING: ParticleSet is empty on writing as array at time 1.58112e+07
# WARNING: ParticleSet is empty on writing as array at time 1.58544e+07
#  18%|█▊        | 15897600.0/90374400.0 [00:38<02:46, 446842.75it/s]WARNING: ParticleSet is empty on writing as array at time 1.58976e+07
# WARNING: ParticleSet is empty on writing as array at time 1.59408e+07
#  18%|█▊        | 15984000.0/90374400.0 [00:38<03:15, 379732.18it/s]WARNING: ParticleSet is empty on writing as array at time 1.5984e+07
#  18%|█▊        | 16027200.0/90374400.0 [00:38<03:31, 350750.80it/s]WARNING: ParticleSet is empty on writing as array at time 1.60272e+07
#  18%|█▊        | 16070400.0/90374400.0 [00:39<03:25, 361890.90it/s]WARNING: ParticleSet is empty on writing as array at time 1.60704e+07
# WARNING: ParticleSet is empty on writing as array at time 1.61136e+07
#  18%|█▊        | 16156800.0/90374400.0 [00:39<03:07, 395709.27it/s]WARNING: ParticleSet is empty on writing as array at time 1.61568e+07
#  18%|█▊        | 16200000.0/90374400.0 [00:39<03:24, 362817.85it/s]WARNING: ParticleSet is empty on writing as array at time 1.62e+07
# WARNING: ParticleSet is empty on writing as array at time 1.62432e+07
#  18%|█▊        | 16286400.0/90374400.0 [00:39<03:10, 388766.71it/s]WARNING: ParticleSet is empty on writing as array at time 1.62864e+07
#  18%|█▊        | 16329600.0/90374400.0 [00:39<03:08, 392258.78it/s]WARNING: ParticleSet is empty on writing as array at time 1.63296e+07
#  18%|█▊        | 16372800.0/90374400.0 [00:39<03:10, 388860.36it/s]WARNING: ParticleSet is empty on writing as array at time 1.63728e+07
# WARNING: ParticleSet is empty on writing as array at time 1.6416e+07
#  18%|█▊        | 16459200.0/90374400.0 [00:39<02:52, 429134.34it/s]WARNING: ParticleSet is empty on writing as array at time 1.64592e+07
# WARNING: ParticleSet is empty on writing as array at time 1.65024e+07
#  18%|█▊        | 16545600.0/90374400.0 [00:40<02:42, 454649.54it/s]WARNING: ParticleSet is empty on writing as array at time 1.65456e+07
# WARNING: ParticleSet is empty on writing as array at time 1.65888e+07
#  18%|█▊        | 16632000.0/90374400.0 [00:40<02:36, 472169.56it/s]WARNING: ParticleSet is empty on writing as array at time 1.6632e+07
# WARNING: ParticleSet is empty on writing as array at time 1.66752e+07
#  18%|█▊        | 16718400.0/90374400.0 [00:40<02:26, 501134.33it/s]WARNING: ParticleSet is empty on writing as array at time 1.67184e+07
# WARNING: ParticleSet is empty on writing as array at time 1.67616e+07
#  19%|█▊        | 16804800.0/90374400.0 [00:40<02:27, 497404.17it/s]WARNING: ParticleSet is empty on writing as array at time 1.68048e+07
# WARNING: ParticleSet is empty on writing as array at time 1.6848e+07
#  19%|█▊        | 16891200.0/90374400.0 [00:40<02:45, 443853.09it/s]WARNING: ParticleSet is empty on writing as array at time 1.68912e+07
# WARNING: ParticleSet is empty on writing as array at time 1.69344e+07
#  19%|█▉        | 16977600.0/90374400.0 [00:41<02:46, 442039.75it/s]WARNING: ParticleSet is empty on writing as array at time 1.69776e+07
# WARNING: ParticleSet is empty on writing as array at time 1.70208e+07
#  19%|█▉        | 17064000.0/90374400.0 [00:41<02:49, 433471.84it/s]WARNING: ParticleSet is empty on writing as array at time 1.7064e+07
# WARNING: ParticleSet is empty on writing as array at time 1.71072e+07
#  19%|█▉        | 17150400.0/90374400.0 [00:41<03:32, 344776.98it/s]WARNING: ParticleSet is empty on writing as array at time 1.71504e+07
# WARNING: ParticleSet is empty on writing as array at time 1.71936e+07
#  19%|█▉        | 17236800.0/90374400.0 [00:41<03:17, 370594.15it/s]WARNING: ParticleSet is empty on writing as array at time 1.72368e+07
#  19%|█▉        | 17280000.0/90374400.0 [00:41<03:13, 377636.63it/s]WARNING: ParticleSet is empty on writing as array at time 1.728e+07
#  19%|█▉        | 17323200.0/90374400.0 [00:42<03:09, 384876.81it/s]WARNING: ParticleSet is empty on writing as array at time 1.73232e+07
#  19%|█▉        | 17366400.0/90374400.0 [00:42<03:09, 386199.04it/s]WARNING: ParticleSet is empty on writing as array at time 1.73664e+07
#  19%|█▉        | 17409600.0/90374400.0 [00:42<03:27, 350889.14it/s]WARNING: ParticleSet is empty on writing as array at time 1.74096e+07
# WARNING: ParticleSet is empty on writing as array at time 1.74528e+07
#  19%|█▉        | 17496000.0/90374400.0 [00:42<03:05, 393006.14it/s]WARNING: ParticleSet is empty on writing as array at time 1.7496e+07
#  19%|█▉        | 17539200.0/90374400.0 [00:42<03:05, 392619.27it/s]WARNING: ParticleSet is empty on writing as array at time 1.75392e+07
#  19%|█▉        | 17582400.0/90374400.0 [00:42<03:16, 370487.10it/s]WARNING: ParticleSet is empty on writing as array at time 1.75824e+07
#  20%|█▉        | 17625600.0/90374400.0 [00:42<03:13, 375498.93it/s]WARNING: ParticleSet is empty on writing as array at time 1.76256e+07
#  20%|█▉        | 17668800.0/90374400.0 [00:42<03:13, 375818.81it/s]WARNING: ParticleSet is empty on writing as array at time 1.76688e+07
#  20%|█▉        | 17712000.0/90374400.0 [00:43<03:11, 380279.10it/s]WARNING: ParticleSet is empty on writing as array at time 1.7712e+07
#  20%|█▉        | 17755200.0/90374400.0 [00:43<03:11, 378698.20it/s]WARNING: ParticleSet is empty on writing as array at time 1.77552e+07
#  20%|█▉        | 17798400.0/90374400.0 [00:43<03:08, 384668.31it/s]WARNING: ParticleSet is empty on writing as array at time 1.77984e+07
#  20%|█▉        | 17841600.0/90374400.0 [00:43<03:05, 391205.99it/s]WARNING: ParticleSet is empty on writing as array at time 1.78416e+07
# WARNING: ParticleSet is empty on writing as array at time 1.78848e+07
#  20%|█▉        | 17928000.0/90374400.0 [00:43<02:30, 480557.75it/s]WARNING: ParticleSet is empty on writing as array at time 1.7928e+07
# WARNING: ParticleSet is empty on writing as array at time 1.79712e+07
#  20%|█▉        | 18014400.0/90374400.0 [00:43<02:26, 493191.71it/s]WARNING: ParticleSet is empty on writing as array at time 1.80144e+07
# WARNING: ParticleSet is empty on writing as array at time 1.80576e+07
#  20%|██        | 18100800.0/90374400.0 [00:43<02:28, 487328.87it/s]WARNING: ParticleSet is empty on writing as array at time 1.81008e+07
# WARNING: ParticleSet is empty on writing as array at time 1.8144e+07
#  20%|██        | 18187200.0/90374400.0 [00:44<02:42, 444088.38it/s]WARNING: ParticleSet is empty on writing as array at time 1.81872e+07
# WARNING: ParticleSet is empty on writing as array at time 1.82304e+07
#  20%|██        | 18273600.0/90374400.0 [00:44<02:40, 448796.85it/s]WARNING: ParticleSet is empty on writing as array at time 1.82736e+07
# WARNING: ParticleSet is empty on writing as array at time 1.83168e+07
#  20%|██        | 18360000.0/90374400.0 [00:44<02:37, 457147.83it/s]WARNING: ParticleSet is empty on writing as array at time 1.836e+07
# WARNING: ParticleSet is empty on writing as array at time 1.84032e+07
#  20%|██        | 18446400.0/90374400.0 [00:44<02:40, 448339.53it/s]WARNING: ParticleSet is empty on writing as array at time 1.84464e+07
# WARNING: ParticleSet is empty on writing as array at time 1.84896e+07
# ...
# WARNING: ParticleSet is empty on writing as array at time 8.39376e+07
#  93%|█████████▎| 83980800.0/90374400.0 [02:53<00:11, 550866.99it/s]WARNING: ParticleSet is empty on writing as array at time 8.39808e+07
# WARNING: ParticleSet is empty on writing as array at time 8.4024e+07
#  93%|█████████▎| 84067200.0/90374400.0 [02:53<00:11, 570425.79it/s]WARNING: ParticleSet is empty on writing as array at time 8.40672e+07
# WARNING: ParticleSet is empty on writing as array at time 8.41104e+07
#  93%|█████████▎| 84153600.0/90374400.0 [02:53<00:10, 589405.03it/s]WARNING: ParticleSet is empty on writing as array at time 8.41536e+07
# WARNING: ParticleSet is empty on writing as array at time 8.41968e+07
#  93%|█████████▎| 84240000.0/90374400.0 [02:53<00:10, 574976.24it/s]WARNING: ParticleSet is empty on writing as array at time 8.424e+07
# WARNING: ParticleSet is empty on writing as array at time 8.42832e+07
#  93%|█████████▎| 84326400.0/90374400.0 [02:53<00:11, 517093.97it/s]WARNING: ParticleSet is empty on writing as array at time 8.43264e+07
# WARNING: ParticleSet is empty on writing as array at time 8.43696e+07
#  93%|█████████▎| 84412800.0/90374400.0 [02:54<00:11, 517647.34it/s]WARNING: ParticleSet is empty on writing as array at time 8.44128e+07
# WARNING: ParticleSet is empty on writing as array at time 8.4456e+07
#  93%|█████████▎| 84499200.0/90374400.0 [02:54<00:11, 524496.55it/s]WARNING: ParticleSet is empty on writing as array at time 8.44992e+07
# WARNING: ParticleSet is empty on writing as array at time 8.45424e+07
#  94%|█████████▎| 84585600.0/90374400.0 [02:54<00:10, 551961.87it/s]WARNING: ParticleSet is empty on writing as array at time 8.45856e+07
# WARNING: ParticleSet is empty on writing as array at time 8.46288e+07
#  94%|█████████▎| 84672000.0/90374400.0 [02:54<00:09, 579375.55it/s]WARNING: ParticleSet is empty on writing as array at time 8.4672e+07
# WARNING: ParticleSet is empty on writing as array at time 8.47152e+07
#  94%|█████████▍| 84758400.0/90374400.0 [02:54<00:09, 600717.72it/s]WARNING: ParticleSet is empty on writing as array at time 8.47584e+07
# WARNING: ParticleSet is empty on writing as array at time 8.48016e+07
#  94%|█████████▍| 84844800.0/90374400.0 [02:54<00:09, 589331.25it/s]WARNING: ParticleSet is empty on writing as array at time 8.48448e+07
# WARNING: ParticleSet is empty on writing as array at time 8.4888e+07
#  94%|█████████▍| 84931200.0/90374400.0 [02:55<00:10, 534118.74it/s]WARNING: ParticleSet is empty on writing as array at time 8.49312e+07
# WARNING: ParticleSet is empty on writing as array at time 8.49744e+07
#  94%|█████████▍| 85017600.0/90374400.0 [02:55<00:09, 549752.83it/s]WARNING: ParticleSet is empty on writing as array at time 8.50176e+07
# WARNING: ParticleSet is empty on writing as array at time 8.50608e+07
#  94%|█████████▍| 85104000.0/90374400.0 [02:55<00:09, 553419.56it/s]WARNING: ParticleSet is empty on writing as array at time 8.5104e+07
# WARNING: ParticleSet is empty on writing as array at time 8.51472e+07
#  94%|█████████▍| 85190400.0/90374400.0 [02:55<00:08, 597540.23it/s]WARNING: ParticleSet is empty on writing as array at time 8.51904e+07
# WARNING: ParticleSet is empty on writing as array at time 8.52336e+07
#  94%|█████████▍| 85276800.0/90374400.0 [02:55<00:08, 612336.50it/s]WARNING: ParticleSet is empty on writing as array at time 8.52768e+07
# WARNING: ParticleSet is empty on writing as array at time 8.532e+07
#  94%|█████████▍| 85363200.0/90374400.0 [02:55<00:08, 614057.75it/s]WARNING: ParticleSet is empty on writing as array at time 8.53632e+07
# WARNING: ParticleSet is empty on writing as array at time 8.54064e+07
#  95%|█████████▍| 85449600.0/90374400.0 [02:55<00:08, 595772.69it/s]WARNING: ParticleSet is empty on writing as array at time 8.54496e+07
# WARNING: ParticleSet is empty on writing as array at time 8.54928e+07
#  95%|█████████▍| 85536000.0/90374400.0 [02:56<00:08, 544334.65it/s]WARNING: ParticleSet is empty on writing as array at time 8.5536e+07
# WARNING: ParticleSet is empty on writing as array at time 8.55792e+07
#  95%|█████████▍| 85622400.0/90374400.0 [02:56<00:08, 547079.63it/s]WARNING: ParticleSet is empty on writing as array at time 8.56224e+07
# WARNING: ParticleSet is empty on writing as array at time 8.56656e+07
#  95%|█████████▍| 85708800.0/90374400.0 [02:56<00:08, 555470.56it/s]WARNING: ParticleSet is empty on writing as array at time 8.57088e+07
# WARNING: ParticleSet is empty on writing as array at time 8.5752e+07
#  95%|█████████▍| 85795200.0/90374400.0 [02:56<00:07, 575524.71it/s]WARNING: ParticleSet is empty on writing as array at time 8.57952e+07
# WARNING: ParticleSet is empty on writing as array at time 8.58384e+07
#  95%|█████████▌| 85881600.0/90374400.0 [02:56<00:07, 595464.41it/s]WARNING: ParticleSet is empty on writing as array at time 8.58816e+07
# WARNING: ParticleSet is empty on writing as array at time 8.59248e+07
#  95%|█████████▌| 85968000.0/90374400.0 [02:56<00:07, 621574.52it/s]WARNING: ParticleSet is empty on writing as array at time 8.5968e+07
# WARNING: ParticleSet is empty on writing as array at time 8.60112e+07
#  95%|█████████▌| 86054400.0/90374400.0 [02:57<00:08, 511565.35it/s]WARNING: ParticleSet is empty on writing as array at time 8.60544e+07
# WARNING: ParticleSet is empty on writing as array at time 8.60976e+07
#  95%|█████████▌| 86140800.0/90374400.0 [02:57<00:08, 515529.28it/s]WARNING: ParticleSet is empty on writing as array at time 8.61408e+07
# WARNING: ParticleSet is empty on writing as array at time 8.6184e+07
#  95%|█████████▌| 86227200.0/90374400.0 [02:57<00:07, 547272.72it/s]WARNING: ParticleSet is empty on writing as array at time 8.62272e+07
# WARNING: ParticleSet is empty on writing as array at time 8.62704e+07
#  96%|█████████▌| 86313600.0/90374400.0 [02:57<00:07, 564612.31it/s]WARNING: ParticleSet is empty on writing as array at time 8.63136e+07
# WARNING: ParticleSet is empty on writing as array at time 8.63568e+07
#  96%|█████████▌| 86400000.0/90374400.0 [02:57<00:06, 578107.25it/s]WARNING: ParticleSet is empty on writing as array at time 8.64e+07
# WARNING: ParticleSet is empty on writing as array at time 8.64432e+07
#  96%|█████████▌| 86486400.0/90374400.0 [02:57<00:06, 606123.52it/s]WARNING: ParticleSet is empty on writing as array at time 8.64864e+07
# WARNING: ParticleSet is empty on writing as array at time 8.65296e+07
#  96%|█████████▌| 86572800.0/90374400.0 [02:57<00:06, 628938.09it/s]WARNING: ParticleSet is empty on writing as array at time 8.65728e+07
# WARNING: ParticleSet is empty on writing as array at time 8.6616e+07
#  96%|█████████▌| 86659200.0/90374400.0 [02:58<00:06, 533936.77it/s]WARNING: ParticleSet is empty on writing as array at time 8.66592e+07
# WARNING: ParticleSet is empty on writing as array at time 8.67024e+07
#  96%|█████████▌| 86745600.0/90374400.0 [02:58<00:06, 547417.06it/s]WARNING: ParticleSet is empty on writing as array at time 8.67456e+07
# WARNING: ParticleSet is empty on writing as array at time 8.67888e+07
#  96%|█████████▌| 86832000.0/90374400.0 [02:58<00:06, 574935.43it/s]WARNING: ParticleSet is empty on writing as array at time 8.6832e+07
# WARNING: ParticleSet is empty on writing as array at time 8.68752e+07
#  96%|█████████▌| 86918400.0/90374400.0 [02:58<00:05, 580113.72it/s]WARNING: ParticleSet is empty on writing as array at time 8.69184e+07
# WARNING: ParticleSet is empty on writing as array at time 8.69616e+07
#  96%|█████████▋| 87004800.0/90374400.0 [02:58<00:05, 601314.32it/s]WARNING: ParticleSet is empty on writing as array at time 8.70048e+07
# WARNING: ParticleSet is empty on writing as array at time 8.7048e+07
#  96%|█████████▋| 87091200.0/90374400.0 [02:58<00:05, 618510.82it/s]WARNING: ParticleSet is empty on writing as array at time 8.70912e+07
# WARNING: ParticleSet is empty on writing as array at time 8.71344e+07
#  96%|█████████▋| 87177600.0/90374400.0 [02:58<00:05, 558059.06it/s]WARNING: ParticleSet is empty on writing as array at time 8.71776e+07
# WARNING: ParticleSet is empty on writing as array at time 8.72208e+07
#  97%|█████████▋| 87264000.0/90374400.0 [02:59<00:05, 521534.31it/s]WARNING: ParticleSet is empty on writing as array at time 8.7264e+07
# WARNING: ParticleSet is empty on writing as array at time 8.73072e+07
#  97%|█████████▋| 87350400.0/90374400.0 [02:59<00:06, 481676.64it/s]WARNING: ParticleSet is empty on writing as array at time 8.73504e+07
# WARNING: ParticleSet is empty on writing as array at time 8.73936e+07
#  97%|█████████▋| 87436800.0/90374400.0 [02:59<00:06, 467384.04it/s]WARNING: ParticleSet is empty on writing as array at time 8.74368e+07
# WARNING: ParticleSet is empty on writing as array at time 8.748e+07
#  97%|█████████▋| 87523200.0/90374400.0 [02:59<00:06, 462862.98it/s]WARNING: ParticleSet is empty on writing as array at time 8.75232e+07
# WARNING: ParticleSet is empty on writing as array at time 8.75664e+07
#  97%|█████████▋| 87609600.0/90374400.0 [02:59<00:05, 470028.59it/s]WARNING: ParticleSet is empty on writing as array at time 8.76096e+07
# WARNING: ParticleSet is empty on writing as array at time 8.76528e+07
#  97%|█████████▋| 87696000.0/90374400.0 [03:00<00:05, 473027.12it/s]WARNING: ParticleSet is empty on writing as array at time 8.7696e+07
# WARNING: ParticleSet is empty on writing as array at time 8.77392e+07
#  97%|█████████▋| 87782400.0/90374400.0 [03:00<00:05, 470600.44it/s]WARNING: ParticleSet is empty on writing as array at time 8.77824e+07
# WARNING: ParticleSet is empty on writing as array at time 8.78256e+07
#  97%|█████████▋| 87868800.0/90374400.0 [03:00<00:05, 462784.25it/s]WARNING: ParticleSet is empty on writing as array at time 8.78688e+07
# WARNING: ParticleSet is empty on writing as array at time 8.7912e+07
#  97%|█████████▋| 87955200.0/90374400.0 [03:00<00:05, 415891.83it/s]WARNING: ParticleSet is empty on writing as array at time 8.79552e+07
#  97%|█████████▋| 87998400.0/90374400.0 [03:00<00:05, 410940.66it/s]WARNING: ParticleSet is empty on writing as array at time 8.79984e+07
#  97%|█████████▋| 88041600.0/90374400.0 [03:00<00:05, 393412.52it/s]WARNING: ParticleSet is empty on writing as array at time 8.80416e+07
# WARNING: ParticleSet is empty on writing as array at time 8.80848e+07
#  98%|█████████▊| 88128000.0/90374400.0 [03:01<00:05, 394105.40it/s]WARNING: ParticleSet is empty on writing as array at time 8.8128e+07
# WARNING: ParticleSet is empty on writing as array at time 8.81712e+07
#  98%|█████████▊| 88214400.0/90374400.0 [03:01<00:05, 420765.77it/s]WARNING: ParticleSet is empty on writing as array at time 8.82144e+07
#  98%|█████████▊| 88257600.0/90374400.0 [03:01<00:05, 367048.60it/s]WARNING: ParticleSet is empty on writing as array at time 8.82576e+07
#  98%|█████████▊| 88300800.0/90374400.0 [03:01<00:05, 374240.02it/s]WARNING: ParticleSet is empty on writing as array at time 8.83008e+07
#  98%|█████████▊| 88344000.0/90374400.0 [03:01<00:05, 371209.41it/s]WARNING: ParticleSet is empty on writing as array at time 8.8344e+07
#  98%|█████████▊| 88387200.0/90374400.0 [03:01<00:05, 383000.44it/s]WARNING: ParticleSet is empty on writing as array at time 8.83872e+07
# WARNING: ParticleSet is empty on writing as array at time 8.84304e+07
#  98%|█████████▊| 88473600.0/90374400.0 [03:02<00:04, 419776.32it/s]WARNING: ParticleSet is empty on writing as array at time 8.84736e+07
# WARNING: ParticleSet is empty on writing as array at time 8.85168e+07
#  98%|█████████▊| 88560000.0/90374400.0 [03:02<00:03, 484038.93it/s]WARNING: ParticleSet is empty on writing as array at time 8.856e+07
# WARNING: ParticleSet is empty on writing as array at time 8.86032e+07
#  98%|█████████▊| 88646400.0/90374400.0 [03:02<00:03, 526673.34it/s]WARNING: ParticleSet is empty on writing as array at time 8.86464e+07
# WARNING: ParticleSet is empty on writing as array at time 8.86896e+07
#  98%|█████████▊| 88732800.0/90374400.0 [03:02<00:03, 534886.59it/s]WARNING: ParticleSet is empty on writing as array at time 8.87328e+07
# WARNING: ParticleSet is empty on writing as array at time 8.8776e+07
#  98%|█████████▊| 88819200.0/90374400.0 [03:02<00:03, 494496.45it/s]WARNING: ParticleSet is empty on writing as array at time 8.88192e+07
# WARNING: ParticleSet is empty on writing as array at time 8.88624e+07
#  98%|█████████▊| 88905600.0/90374400.0 [03:02<00:03, 486131.65it/s]WARNING: ParticleSet is empty on writing as array at time 8.89056e+07
# WARNING: ParticleSet is empty on writing as array at time 8.89488e+07
#  98%|█████████▊| 88992000.0/90374400.0 [03:03<00:02, 502231.23it/s]WARNING: ParticleSet is empty on writing as array at time 8.8992e+07
# WARNING: ParticleSet is empty on writing as array at time 8.90352e+07
#  99%|█████████▊| 89078400.0/90374400.0 [03:03<00:02, 448990.77it/s]WARNING: ParticleSet is empty on writing as array at time 8.90784e+07
# WARNING: ParticleSet is empty on writing as array at time 8.91216e+07
#  99%|█████████▊| 89164800.0/90374400.0 [03:03<00:02, 415652.34it/s]WARNING: ParticleSet is empty on writing as array at time 8.91648e+07
#  99%|█████████▊| 89208000.0/90374400.0 [03:03<00:03, 388131.64it/s]WARNING: ParticleSet is empty on writing as array at time 8.9208e+07
#  99%|█████████▉| 89251200.0/90374400.0 [03:03<00:03, 342622.26it/s]WARNING: ParticleSet is empty on writing as array at time 8.92512e+07
#  99%|█████████▉| 89294400.0/90374400.0 [03:04<00:03, 327362.03it/s]WARNING: ParticleSet is empty on writing as array at time 8.92944e+07
#  99%|█████████▉| 89337600.0/90374400.0 [03:04<00:03, 273701.69it/s]WARNING: ParticleSet is empty on writing as array at time 8.93376e+07
# WARNING: ParticleSet is empty on writing as array at time 8.93808e+07
#  99%|█████████▉| 89424000.0/90374400.0 [03:04<00:02, 338805.12it/s]WARNING: ParticleSet is empty on writing as array at time 8.9424e+07
#  99%|█████████▉| 89467200.0/90374400.0 [03:04<00:02, 351530.06it/s]WARNING: ParticleSet is empty on writing as array at time 8.94672e+07
# WARNING: ParticleSet is empty on writing as array at time 8.95104e+07
#  99%|█████████▉| 89553600.0/90374400.0 [03:04<00:02, 385449.27it/s]WARNING: ParticleSet is empty on writing as array at time 8.95536e+07
#  99%|█████████▉| 89596800.0/90374400.0 [03:04<00:02, 378561.32it/s]WARNING: ParticleSet is empty on writing as array at time 8.95968e+07
#  99%|█████████▉| 89640000.0/90374400.0 [03:04<00:02, 353087.04it/s]WARNING: ParticleSet is empty on writing as array at time 8.964e+07
#  99%|█████████▉| 89683200.0/90374400.0 [03:05<00:01, 359829.40it/s]WARNING: ParticleSet is empty on writing as array at time 8.96832e+07
#  99%|█████████▉| 89726400.0/90374400.0 [03:05<00:01, 373623.87it/s]WARNING: ParticleSet is empty on writing as array at time 8.97264e+07
#  99%|█████████▉| 89769600.0/90374400.0 [03:05<00:01, 341077.31it/s]WARNING: ParticleSet is empty on writing as array at time 8.97696e+07
# WARNING: ParticleSet is empty on writing as array at time 8.98128e+07
#  99%|█████████▉| 89856000.0/90374400.0 [03:05<00:01, 392580.62it/s]WARNING: ParticleSet is empty on writing as array at time 8.9856e+07
# WARNING: ParticleSet is empty on writing as array at time 8.98992e+07
# 100%|█████████▉| 89942400.0/90374400.0 [03:05<00:01, 413792.39it/s]WARNING: ParticleSet is empty on writing as array at time 8.99424e+07
# WARNING: ParticleSet is empty on writing as array at time 8.99856e+07
# 100%|█████████▉| 90028800.0/90374400.0 [03:05<00:00, 462436.32it/s]WARNING: ParticleSet is empty on writing as array at time 9.00288e+07
# WARNING: ParticleSet is empty on writing as array at time 9.0072e+07
# 100%|█████████▉| 90115200.0/90374400.0 [03:06<00:00, 509733.17it/s]WARNING: ParticleSet is empty on writing as array at time 9.01152e+07
# WARNING: ParticleSet is empty on writing as array at time 9.01584e+07
# 100%|█████████▉| 90201600.0/90374400.0 [03:06<00:00, 531568.11it/s]WARNING: ParticleSet is empty on writing as array at time 9.02016e+07
# WARNING: ParticleSet is empty on writing as array at time 9.02448e+07
# WARNING: ParticleSet is empty on writing as array at time 9.0288e+07
# WARNING: ParticleSet is empty on writing as array at time 9.03312e+07
# 100%|██████████| 90374400.0/90374400.0 [03:06<00:00, 485195.84it/s]

# %% [markdown]
# ### Visualise

# %%
## Load the simulation output
#ds = xr.open_zarr("debris_simulation_output.zarr")
#
## Plot trajectories
#plt.figure(figsize=(10, 6))
#plt.scatter(ds.lon, ds.lat, s=1, c=ds.time, cmap='viridis', marker='o')
#plt.colorbar(label='Time')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.title('Particle Trajectories')
#plt.show()

# %%
# Load the simulation output
ds = xr.open_zarr("debris_simulation_output.zarr")

# Define the geographic boundaries
extent = [13.9, 14.81, 35.6, 36.3]

# Create a GeoAxes with the PlateCarree projection
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent(extent)

# Add land, coastlines, and the border of the map
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Plot the particle trajectories
scatter = ax.scatter(ds.lon, ds.lat, s=1, c=ds.time, cmap='viridis', marker='o', transform=ccrs.PlateCarree())

# Add a colorbar and labels
cbar = plt.colorbar(scatter, ax=ax, label='Time')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Particle Trajectories')

plt.show()
