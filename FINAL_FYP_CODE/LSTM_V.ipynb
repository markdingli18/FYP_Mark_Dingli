# %% [markdown]
# # Sea Surface Current Prediction using LSTM
#
# This notebook outlines the process of loading, inspecting, and preprocessing sea surface current data (`u` and `v` components) for training an LSTM model. The goal is to predict sea surface currents for the next 24 hours based on historical data.

# %% [markdown]
# ### Import Libraries

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.patches as mpatches
import matplotlib.path as mpath
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, TimeDistributed, BatchNormalization, InputLayer
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.losses import MeanSquaredError, MeanAbsoluteError
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.models import load_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score
# Out:
# WARNING:tensorflow:From c:\Users\markd\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Load and Inspect Data
#
# The initial step involves loading the dataset using xarray, which facilitates working with multi-dimensional arrays, and inspecting its structure to understand the available dimensions, coordinates, and variables.

# %%
# Load the dataset
netcdf_file_path = "Data/24_months_SSC_Data.nc"

# Open the data
dataset = xr.open_dataset(netcdf_file_path)

# Print head of dataset
dataset.head()
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 5, lat: 5, lon: 5)
# Coordinates:
#   * time     (time) datetime64[ns] 2021-01-01 ... 2021-01-01T04:00:00
#   * lat      (lat) float32 35.74 35.77 35.79 35.81 35.83
#   * lon      (lon) float32 13.68 13.72 13.76 13.8 13.84
# Data variables:
#     u        (time, lat, lon) float64 ...
#     v        (time, lat, lon) float64 ...
#     stdu     (time, lat, lon) float64 ...
#     stdv     (time, lat, lon) float64 ...
#     cov      (time, lat, lon) float64 ...
#     velo     (time, lat, lon) float64 ...
#     head     (time, lat, lon) float64 ...
# Attributes: (12/17)
#     NC_GLOBAL.Title:                   Near-Real time Surface Ocean Velocity
#     NC_GLOBAL.origin:                  BARK (measured);POZZ (measured);
#     NC_GLOBAL.source:                  HF Radar Derived Surface Currents obta...
#     NC_GLOBAL.history:                 08-Jun-2023 14:45:58
#     NC_GLOBAL.grid_type:               REGULAR
#     NC_GLOBAL.Conventions:             CF-1.4
#     ...                                ...
#     NC_GLOBAL.grid_resolution:         3.0km
#     NC_GLOBAL.geospatial_lat_max:      36.8802
#     NC_GLOBAL.geospatial_lat_min:      35.7447
#     NC_GLOBAL.geospatial_lon_max:      15.3804
#     NC_GLOBAL.geospatial_lon_min:      13.6768
#     NC_GLOBAL.netcdf_library_version:  v2

# %% [markdown]
# ### Convert the dataset to a pandas DataFrame

# %%
# Convert the dataset to a pandas DataFrame
df = dataset.to_dataframe().reset_index()

# Drop columns from the DataFrame
df = df.drop(columns=['stdu', 'stdv', 'cov', 'velo', 'head'])

# Remove rows where 'u' has NaN values
df = df.dropna(subset=['u'])
df = df.dropna(subset=['v'])

df.index = pd.to_datetime(df['time'], format='%d-%m-%Y %H:%M:%S')

df
# Out:
#                                    time        lat      lon         u
# time
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.011902  14.6908 -0.187088  \
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.011902  14.7314 -0.250971
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.034100  14.5286  0.079402
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.034100  14.5692 -0.229349
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.034100  14.6908 -0.394889
# ...                                 ...        ...      ...       ...
# 2023-12-16 12:00:00 2023-12-16 12:00:00  36.880199  14.0419  0.054150
# 2023-12-16 12:00:00 2023-12-16 12:00:00  36.880199  14.0824 -0.062866
# 2023-12-16 12:00:00 2023-12-16 12:00:00  36.880199  14.1230 -0.153775
# 2023-12-16 12:00:00 2023-12-16 12:00:00  36.880199  14.1635 -0.094604
# 2023-12-16 12:00:00 2023-12-16 12:00:00  36.880199  14.2041 -0.019814
#
#                             v
# time
# 2021-01-01 00:00:00 -0.048105
# 2021-01-01 00:00:00 -0.024680
# 2021-01-01 00:00:00  0.039575
# 2021-01-01 00:00:00  0.057154
# 2021-01-01 00:00:00  0.063383
# ...                       ...
# 2023-12-16 12:00:00 -0.289736
# 2023-12-16 12:00:00 -0.480209
# 2023-12-16 12:00:00 -0.579049
# 2023-12-16 12:00:00 -0.582366
# 2023-12-16 12:00:00 -0.580397
#
# [17093019 rows x 5 columns]

# %% [markdown]
# ### Geospatial Visualization
# Define boundaries and coordinates for visualization

# %%
# Define the boundaries for map
boundaries = {
    'min_lon': 14.15,  
    'max_lon': 14.81,  
    'min_lat': 35.79,  
    'max_lat': 36.3   
}

# Define the coordinates 
polygon_coordinates = [
    (14.6, 35.87), 
    (14.35, 36.01), 
    (14.35, 36.09), 
    (14.6, 36.09), 
    (14.6, 35.87)
]

# Create a plot with Cartopy
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([boundaries['min_lon'], boundaries['max_lon'], boundaries['min_lat'], boundaries['max_lat']], crs=ccrs.PlateCarree())

# Add map features
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Plotting all points within the boundary from the dataframe 'df'
ax.scatter(df['lon'], df['lat'], s=10, color='blue', marker='o', alpha=0.5, transform=ccrs.Geodetic())

# Create a red polygon and add it to the plot
red_polygon = mpatches.Polygon(polygon_coordinates, closed=True, edgecolor='red', facecolor='none', linewidth=3, transform=ccrs.Geodetic())
ax.add_patch(red_polygon)

# Gridlines and labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False

plt.show()

# %% [markdown]
# ### Data Filtering
# Filter the DataFrame to include only data points within the specified polygon.

# %%
# Convert the polygon coordinates to a Path object
polygon_path = mpath.Path(polygon_coordinates)

# Use the Path object to find points inside the polygon
inside_polygon = df.apply(lambda row: polygon_path.contains_point((row['lon'], row['lat'])), axis=1)
df_inside_polygon = df[inside_polygon]

# Create a plot with Cartopy
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent([boundaries['min_lon'], boundaries['max_lon'], boundaries['min_lat'], boundaries['max_lat']], crs=ccrs.PlateCarree())

# Add map features
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Plotting only the points within the polygon
ax.scatter(df_inside_polygon['lon'], df_inside_polygon['lat'], s=10, color='red', marker='x', alpha=0.5, transform=ccrs.Geodetic())

# Gridlines and labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False

plt.show()

# %% [markdown]
# ### Data Preparation

# %%
# Convert the polygon coordinates to a Path object
polygon_path = mpath.Path(polygon_coordinates)

# Prepare the coordinates as a list of tuples
coordinates = list(zip(df['lon'], df['lat']))

# Check if each coordinate is inside the polygon
inside_mask = [polygon_path.contains_point(coord) for coord in coordinates]

# Filter the DataFrame for points within the polygon
df_inside_polygon = df[inside_mask]

# Removing potential duplicates
df_inside_polygon = df_inside_polygon.drop_duplicates(subset=['lon', 'lat'])

# Count the number of points inside the polygon
num_points_inside_polygon = df_inside_polygon.shape[0]
print(f"Total number of points inside the polygon: {num_points_inside_polygon}\n")
print("Coordinates of the points inside the polygon:")

# Print out all of the coordinate pairs
coordinates_inside = df_inside_polygon[['lon', 'lat']].values
for lon, lat in coordinates_inside:
    print(f"({lon}, {lat})")
# Out:
# Total number of points inside the polygon: 37
#
# Coordinates of the points inside the polygon:
# (14.528599739074707, 36.03409957885742)
# (14.569199562072754, 36.03409957885742)
# (14.528599739074707, 36.056400299072266)
# (14.569199562072754, 36.056400299072266)
# (14.528599739074707, 36.07870101928711)
# (14.569199562072754, 36.07870101928711)
# (14.447500228881836, 36.07870101928711)
# (14.447500228881836, 36.056400299072266)
# (14.406900405883789, 36.07870101928711)
# (14.528599739074707, 36.01190185546875)
# (14.569199562072754, 36.01190185546875)
# (14.48799991607666, 36.07870101928711)
# (14.48799991607666, 36.03409957885742)
# (14.48799991607666, 36.056400299072266)
# (14.569199562072754, 35.96730041503906)
# (14.569199562072754, 35.989601135253906)
# (14.528599739074707, 35.989601135253906)
# (14.48799991607666, 36.01190185546875)
# (14.447500228881836, 36.03409957885742)
# (14.447500228881836, 36.01190185546875)
# (14.366399765014648, 36.07870101928711)
# (14.447500228881836, 35.989601135253906)
# (14.48799991607666, 35.989601135253906)
# (14.366399765014648, 36.03409957885742)
# (14.406900405883789, 36.03409957885742)
# (14.366399765014648, 36.056400299072266)
# (14.406900405883789, 36.056400299072266)
# (14.406900405883789, 36.01190185546875)
# (14.528599739074707, 35.96730041503906)
# (14.569199562072754, 35.90060043334961)
# (14.569199562072754, 35.92279815673828)
# (14.528599739074707, 35.945098876953125)
# (14.569199562072754, 35.945098876953125)
# (14.48799991607666, 35.96730041503906)
# (14.406900405883789, 35.989601135253906)
# (14.366399765014648, 36.01190185546875)
# (14.447500228881836, 35.96730041503906)

# %%
# Assuming 'inside_mask' is a list of booleans indicating whether each point is inside the polygon
inside_mask = [polygon_path.contains_point((lon, lat)) for lon, lat in zip(df['lon'], df['lat'])]

# Convert 'inside_mask' to a pandas Series to use as a boolean indexer
inside_series = pd.Series(inside_mask, index=df.index)

# Filter the original DataFrame using the boolean Series
final_df = df[inside_series]

# Display the resulting DataFrame
final_df
# Out:
#                                    time        lat      lon         u
# time
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.034100  14.5286  0.079402  \
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.034100  14.5692 -0.229349
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.056400  14.5286  0.046379
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.056400  14.5692 -0.235254
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.078701  14.5286  0.023732
# ...                                 ...        ...      ...       ...
# 2023-11-30 06:00:00 2023-11-30 06:00:00  35.989601  14.5692 -0.100506
# 2023-11-30 06:00:00 2023-11-30 06:00:00  36.011902  14.5286 -0.073141
# 2023-11-30 06:00:00 2023-11-30 06:00:00  36.034100  14.5286  0.039092
# 2023-11-30 06:00:00 2023-11-30 06:00:00  36.056400  14.5286  0.357385
# 2023-11-30 06:00:00 2023-11-30 06:00:00  36.078701  14.4880  0.156631
#
#                             v
# time
# 2021-01-01 00:00:00  0.039575
# 2021-01-01 00:00:00  0.057154
# 2021-01-01 00:00:00  0.059340
# 2021-01-01 00:00:00  0.081921
# 2021-01-01 00:00:00  0.085635
# ...                       ...
# 2023-11-30 06:00:00  0.145137
# 2023-11-30 06:00:00  0.139570
# 2023-11-30 06:00:00  0.133240
# 2023-11-30 06:00:00  0.140942
# 2023-11-30 06:00:00  0.056568
#
# [349264 rows x 5 columns]

# %% [markdown]
# ### Exctract data only for a single pair of coordinates

# %%
# Coordinates 
target_lat = 36.03409957885742
target_lon = 14.528599739074707

# Filter the DataFrame for the exact coordinates
df_point = final_df[(final_df['lat'] == target_lat) & (final_df['lon'] == target_lon)]

# Display the filtered DataFrame
df_point
# Out:
#                                    time      lat      lon         u         v
# time
# 2021-01-01 00:00:00 2021-01-01 00:00:00  36.0341  14.5286  0.079402  0.039575
# 2021-01-01 13:00:00 2021-01-01 13:00:00  36.0341  14.5286  0.162881 -0.039021
# 2021-01-01 14:00:00 2021-01-01 14:00:00  36.0341  14.5286  0.144165 -0.023481
# 2021-01-01 15:00:00 2021-01-01 15:00:00  36.0341  14.5286  0.280085 -0.033406
# 2021-01-01 16:00:00 2021-01-01 16:00:00  36.0341  14.5286  0.115884 -0.089223
# ...                                 ...      ...      ...       ...       ...
# 2023-11-26 06:00:00 2023-11-26 06:00:00  36.0341  14.5286  0.475833 -0.287090
# 2023-11-26 19:00:00 2023-11-26 19:00:00  36.0341  14.5286  0.226526 -0.003036
# 2023-11-28 18:00:00 2023-11-28 18:00:00  36.0341  14.5286 -0.318017 -0.002943
# 2023-11-29 19:00:00 2023-11-29 19:00:00  36.0341  14.5286 -0.022189 -0.054151
# 2023-11-30 06:00:00 2023-11-30 06:00:00  36.0341  14.5286  0.039092  0.133240
#
# [13158 rows x 5 columns]

# %%
df1_v = df_point['v']

plt.figure(figsize=(10, 5))  
plt.plot(df1_v.index, df1_v, label='v component')  
plt.title('Sea Surface Current "v" Component Over Time')  
plt.xlabel('Time')  
plt.ylabel('v Component Value')  
plt.legend()  
plt.grid(True)  
plt.show()

# %% [markdown]
# ### Convert the time series data into a format suitable for LSTM

# %%
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = [] 
    y = []
    for i in range(len(df_as_np) - window_size):
        row = [[a] for a in df_as_np[i:i+5]]
        X.append(row)
        label = df_as_np[i+5]
        y.append(label)
    return np.array(X), np.array(y)

window_size = 5
X, y = df_to_X_y(df_point['v'], window_size=window_size)
X.shape, y.shape
# Out:
# ((13153, 5, 1), (13153,))

# %% [markdown]
# ### Split the data

# %%
def train_val_test_split(X, y, train_size, val_size, test_size):
    # Calculate the indices for the end of each segment
    total_size = len(X)
    train_end = int(total_size * train_size)
    val_end = train_end + int(total_size * val_size)
    
    # Split the data
    X_train = X[:train_end]
    y_train = y[:train_end]
    
    X_val = X[train_end:val_end]
    y_val = y[train_end:val_end]
    
    X_test = X[val_end:]
    y_test = y[val_end:]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

train_size = 0.70
val_size = 0.15
test_size = 1 - (train_size + val_size)

X_train, y_train, X_val, y_val, X_test, y_test = train_val_test_split(X, y, train_size, val_size, test_size)

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((9207, 5, 1), (9207,), (1972, 5, 1), (1972,), (1974, 5, 1), (1974,))

# %% [markdown]
# ### Define & Compile the Model

# %%
# Define the model
model = Sequential()
model.add(InputLayer((5, 1)))
model.add(LSTM(128, return_sequences=True))  # More units and return sequences for stacking LSTMs
model.add(Dropout(0.2))  # Regularization with dropout
model.add(LSTM(64, return_sequences=True))  # Stacking another LSTM layer
model.add(Dropout(0.2))  # Regularization with dropout
model.add(LSTM(32))  # Last LSTM does not return sequences
model.add(Dropout(0.2))  # Regularization with dropout
model.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))  # Dense layer with L2 regularization
model.add(Dense(1, activation='linear'))

model.summary()

# Define ModelCheckpoint callback to save the best model
cp = ModelCheckpoint(filepath="Data/LSTM/Saved_Models/lstm_single_v_target_best_model",
                     save_best_only=True,
                     monitor='val_loss',  
                     mode='min',  
                     verbose=0)   

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5,
                               restore_best_weights=True,
                               verbose=1)             

# Compile the model
model.compile(loss=MeanSquaredError(),
              optimizer=Adam(learning_rate=0.0001))
# Out:
# WARNING:tensorflow:From c:\Users\markd\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 128)            66560
#
#  dropout (Dropout)           (None, 5, 128)            0
#
#  lstm_1 (LSTM)               (None, 5, 64)             49408
#
#  dropout_1 (Dropout)         (None, 5, 64)             0
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 16)                528
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 128929 (503.63 KB)
# Trainable params: 128929 (503.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the Model

# %%
# Fit the model with the training data and validate with the validation data
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=20,
                    callbacks=[cp, early_stopping])

# Plotting the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# WARNING:tensorflow:From c:\Users\markd\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 288/288 [==============================] - ETA: 0s - loss: 0.2000INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 24s 61ms/step - loss: 0.2000 - val_loss: 0.1736
# Epoch 2/20
# 288/288 [==============================] - ETA: 0s - loss: 0.1570INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 17s 58ms/step - loss: 0.1570 - val_loss: 0.1364
# Epoch 3/20
# 286/288 [============================>.] - ETA: 0s - loss: 0.1239INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 16s 56ms/step - loss: 0.1238 - val_loss: 0.1067
# Epoch 4/20
# 288/288 [==============================] - ETA: 0s - loss: 0.0970INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 16s 56ms/step - loss: 0.0970 - val_loss: 0.0827
# Epoch 5/20
# 286/288 [============================>.] - ETA: 0s - loss: 0.0756INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0755 - val_loss: 0.0632
# Epoch 6/20
# 288/288 [==============================] - ETA: 0s - loss: 0.0586INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0586 - val_loss: 0.0479
# Epoch 7/20
# 286/288 [============================>.] - ETA: 0s - loss: 0.0455INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 16s 57ms/step - loss: 0.0454 - val_loss: 0.0361
# Epoch 8/20
# 288/288 [==============================] - ETA: 0s - loss: 0.0352INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 17s 60ms/step - loss: 0.0352 - val_loss: 0.0273
# Epoch 9/20
# 286/288 [============================>.] - ETA: 0s - loss: 0.0274INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 19s 68ms/step - loss: 0.0274 - val_loss: 0.0204
# Epoch 10/20
# 287/288 [============================>.] - ETA: 0s - loss: 0.0215INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0214 - val_loss: 0.0153
# Epoch 11/20
# 286/288 [============================>.] - ETA: 0s - loss: 0.0171INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 18s 63ms/step - loss: 0.0171 - val_loss: 0.0114
# Epoch 12/20
# 287/288 [============================>.] - ETA: 0s - loss: 0.0139INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0139 - val_loss: 0.0087
# Epoch 13/20
# 287/288 [============================>.] - ETA: 0s - loss: 0.0116INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 18s 61ms/step - loss: 0.0116 - val_loss: 0.0068
# Epoch 14/20
# 288/288 [==============================] - ETA: 0s - loss: 0.0100INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 16s 56ms/step - loss: 0.0100 - val_loss: 0.0054
# Epoch 15/20
# 288/288 [==============================] - ETA: 0s - loss: 0.0090INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 17s 59ms/step - loss: 0.0090 - val_loss: 0.0050
# Epoch 16/20
# 287/288 [============================>.] - ETA: 0s - loss: 0.0083INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 17s 58ms/step - loss: 0.0083 - val_loss: 0.0040
# Epoch 17/20
# 287/288 [============================>.] - ETA: 0s - loss: 0.0078INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 39s 137ms/step - loss: 0.0078 - val_loss: 0.0035
# Epoch 18/20
# 287/288 [============================>.] - ETA: 0s - loss: 0.0075INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 20s 69ms/step - loss: 0.0075 - val_loss: 0.0034
# Epoch 19/20
# 287/288 [============================>.] - ETA: 0s - loss: 0.0073INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# INFO:tensorflow:Assets written to: Data/LSTM/Saved_Models\lstm_single_v_target_best_model\assets
# 288/288 [==============================] - 18s 64ms/step - loss: 0.0073 - val_loss: 0.0032
# Epoch 20/20
# 288/288 [==============================] - 10s 33ms/step - loss: 0.0073 - val_loss: 0.0032

# %% [markdown]
# ### Evaluation on Test Set

# %%
# Load the model
# model = load_model("Data/LSTM/Saved_Models/lstm_single_u_target_best_model")
model = load_model("Data/LSTM/Saved_Models/lstm_single_v_target_best_model")


# Make predictions on the test data
test_predictions = model.predict(X_test)

print("y_test shape:", y_test.shape)
print("test_predictions shape:", test_predictions.shape)
# Out:
# WARNING:tensorflow:From c:\Users\markd\anaconda3\lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# WARNING:tensorflow:From c:\Users\markd\anaconda3\lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# 62/62 [==============================] - 2s 14ms/step
# y_test shape: (1974,)
# test_predictions shape: (1974, 1)

# %%
# Calculate metrics
mse_v = mean_squared_error(y_test, test_predictions)
m_ae_v = mean_absolute_error(y_test, test_predictions)
r2_v = r2_score(y_test, test_predictions)
explained_variance_v = explained_variance_score(y_test, test_predictions)

# Output the error metrics
print("Test MSE for 'v' component:", mse_v)
print("Test MAE for 'v' component:", m_ae_v)
print("Test R-squared for 'v' component:", r2_v)
print("Test Explained Variance for 'v' component:", explained_variance_v)
# Out:
# Test MSE for 'v' component: 0.0034144461552393186
# Test MAE for 'v' component: 0.0397711281401556
# Test R-squared for 'v' component: 0.7681236805037378
# Test Explained Variance for 'v' component: 0.7688760337222249

# %%
test_results = pd.DataFrame({
    'Test Predictions v': test_predictions.flatten(),
    'Actuals v': y_test
})

test_results
# Out:
#       Test Predictions v  Actuals v
# 0              -0.052377  -0.022986
# 1              -0.032314  -0.007840
# 2              -0.016570  -0.004065
# 3              -0.010617   0.001152
# 4              -0.005633  -0.008245
# ...                  ...        ...
# 1969           -0.270325  -0.287090
# 1970           -0.263654  -0.003036
# 1971           -0.061856  -0.002943
# 1972           -0.013410  -0.054151
# 1973           -0.046095   0.133240
#
# [1974 rows x 2 columns]

# %%
# Plot for the 'u' component test predictions vs actuals
plt.figure(figsize=(10, 5))
plt.plot(test_results.index, test_results['Test Predictions v'], label='Test Predictions v', color='blue', linestyle='--')
plt.plot(test_results.index, test_results['Actuals v'], label='Actuals v', color='red', alpha=0.7)
plt.title('Test Predictions vs Actuals for v Component')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ### Making 24-Hour Predictions on the Test Set

# %%
# Take the first 24 predictions for comparison
first_24_predictions = test_predictions[:24]
first_24_actual = y_test[:24]

# Calculate metrics for the first 24-hour predictions
mse_24h = mean_squared_error(first_24_actual, first_24_predictions)
mae_24h = mean_absolute_error(first_24_actual, first_24_predictions)
r2_24h = r2_score(first_24_actual, first_24_predictions)
explained_variance_24h = explained_variance_score(first_24_actual, first_24_predictions)
# Output the error metrics for the 24-hour predictions
print("First 24-Hour MSE:", mse_24h)
print("First 24-Hour MAE:", mae_24h)

# Plot for the first 24-hour predictions vs actuals
plt.figure(figsize=(12, 6))
plt.plot(range(24), first_24_actual, label='Actual', marker='o', color='red')
plt.plot(range(24), first_24_predictions, label='Predicted', marker='x', color='blue', linestyle='--')
plt.title('First 24-Hour Forecast vs Actual')
plt.xlabel('Hour')
plt.ylabel('v Component Value')
plt.xticks(range(24))  
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10912\1496659728.py in <cell line: 2>()
#       1 # Take the first 24 predictions for comparison
# ----> 2 first_24_predictions = test_predictions[:24]
#       3 first_24_actual = y_test[:24]
#       4
#       5 # Calculate metrics for the first 24-hour predictions
#
# NameError: name 'test_predictions' is not defined
