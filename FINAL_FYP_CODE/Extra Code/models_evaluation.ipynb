# %% [markdown]
# # Model Evaluation for 4th of August 2023 Prediction

# %% [markdown]
# ### LSTM_U

# %%
import numpy as np

lstm_u_mae_values = [0.06108554717145389, 0.06540178835727949, 0.27017779957200155, 0.4191201531496805, 0.23282335884857464,
              0.05013517712894045, 0.050484753608618094, 0.08900179101651136, 0.05872434321910889, 0.06931665547807252,
              0.027900122749753394, 0.053315444730983354, 0.05379749083481605, 0.0349735396140012, 0.03716759524977071,
              0.04047005151885849, 0.0543720211459473, 0.05937918207302967, 0.05090706371383844, 0.06556309103622539,
              0.064213053962765, 0.091944696288818, 0.07947235137120495, 0.08146665037097364, 0.05787147793813754,
              0.07023683902356578, 0.08203857247434233, 0.07313875131890932, 0.2435463228052995, 0.08622150060341523, 
              0.19159777811756087, 0.24320531926974734, 0.21360758601351373, 1.402222516584806, 0.08609451169372799,
              0.1126734686630478, 0.20293174525285765]  

lstm_u_mse_values = [0.00522638016930508, 0.005102039683747252, 0.09896044666532265, 0.2624668417011826, 0.06740287196305002,
              0.003591466025064981, 0.004785102876909245, 0.011349529064216747, 0.00469989671856906, 0.0073310469053799515,
              0.0015893195659487582, 0.004462906431005693, 0.0042974161575633435, 0.002129636919114176, 0.0025918471671267647,
              0.0025753944017059224, 0.004062528860270504, 0.0056458877037079734, 0.004815279012025143, 0.0058326562439374756,
              0.0049901461633801835, 0.014900504909805748, 0.008365283553933326, 0.009625821390095672, 0.005324695518804208,
              0.008673922232318299, 0.008893223835232614, 0.007397760655330393, 0.15144364598324664, 0.010855566607626875,
              0.08118996126210297, 0.15355354423760442, 0.11213607320054737, 3.178327737340824, 0.007456369387469529,
              0.01279916844237975, 0.04141355791052804] 

lstm_u_rmse_values = [0.07229370767435489, 0.07142856350051603, 0.3145797937969358, 0.5123151780897991, 0.2596206308501888,
               0.059928841345924425, 0.06917443803103315, 0.10653416852924111, 0.06855579274261993, 0.08562153295392434,
               0.03986627103139643, 0.0668049880697968, 0.06555468066860934, 0.04614798932905069, 0.05091018726273519,
               0.05074834383214808, 0.06373797031809614, 0.07513912232457852, 0.06939221146515755, 0.07637182886338048,
               0.07064096660847856, 0.12206762433096562, 0.09146192406642956, 0.09811127045398847, 0.07297051129603113,
               0.09313389411121119, 0.09430389088066629, 0.08601023575906762, 0.3891576107225023, 0.10419005042530152,
               0.28493852189920366, 0.39185908722090956, 0.33486724713018345, 1.782786509187464, 0.08635027149621204,
               0.11313340992995725, 0.20350321351400827] 

# Calculating the mean
lstm_u_mean_mae = np.mean(lstm_u_mae_values)
lstm_u_mean_mse = np.mean(lstm_u_mse_values)
lstm_u_mean_rmse = np.mean(lstm_u_rmse_values)

# Calculating the standard deviation
lstm_u_std_mae = np.std(lstm_u_mae_values)
lstm_u_std_mse = np.std(lstm_u_mse_values)
lstm_u_std_rmse = np.std(lstm_u_rmse_values)

# Calculating the IQR
lstm_u_iqr_mae = np.percentile(lstm_u_mae_values, 75) - np.percentile(lstm_u_mae_values, 25)
lstm_u_iqr_mse = np.percentile(lstm_u_mse_values, 75) - np.percentile(lstm_u_mse_values, 25)
lstm_u_iqr_rmse = np.percentile(lstm_u_rmse_values, 75) - np.percentile(lstm_u_rmse_values, 25)

# %% [markdown]
# ### LSTM_V

# %%
lstm_v_mae_values = [0.3679017230624209, 0.46575332597373986, 0.3022444530372321, 0.36528784613708537, 0.3381885495331005,
              0.06736732694989067, 0.054119873530827596, 0.05608027316364813, 0.04684351216379584, 0.05979004017777989,
              0.07572303170573809, 0.043180227831838745, 0.04237280495931578, 0.06572383177295216, 0.04954834624676635,
              0.04038072829021496, 0.03601977143593443, 0.06989793330203996, 0.05749050933461447, 0.05219508275442134,
              0.05845051135161675, 0.2528627167594539, 0.10385944046491992, 0.09195128136902715, 0.048107539272815185,
              0.04421128326301398, 0.052989123242683824, 0.5387065585635925, 0.13681444102571508, 0.36565769494417655,
              0.22297531981664534, 0.17767675741801958, 0.19370453653374112, 0.1045633808279058, 0.07972085596536166,
              0.06255286772078933, 0.12595831198987914]  

lstm_v_mse_values = [0.2047845881456747, 0.3382404772586884, 0.14146385441578435, 0.20552258212926364, 0.17599942062910676,
              0.006816653955741297, 0.005412777383391988, 0.005319160875378493, 0.003847065624712416, 0.005482594867939371,
              0.010089862038412268, 0.004389902331031583, 0.0027121674249497053, 0.005595394369264471, 0.0045808706780193385,
              0.002296362679512815, 0.002071642614076025, 0.006682668510287291, 0.005355617166481304, 0.004049197910667803,
              0.004764428667743285, 0.12254163704022177, 0.01599301687514287, 0.010986929654419655, 0.003327407472766424,
              0.0031991063267935577, 0.00388496232427395, 0.45315141752435695, 0.02291971428983229, 0.3206738754352008,
              0.08570405463323884, 0.0567954532590213, 0.07720445536500409, 0.018197434750811918, 0.008603602761959947,
              0.004009632885735164, 0.01735120304699096] 

lstm_v_rmse_values = [0.45253131178480316, 0.581584454106786, 0.37611680953632526, 0.45334598501504747, 0.4195228487569023,
               0.08256303019960748, 0.07357157999793118, 0.07293257759998951, 0.06202471785274332, 0.07404454651045796,
               0.10044830530383411, 0.06625633804423228, 0.052078473719471705, 0.07480236874099958, 0.06768212967999263,
               0.047920378541000855, 0.04551530087867184, 0.08174759024147006, 0.0731820822775719, 0.06363330818579059,
               0.06902484094688872, 0.35005947643253676, 0.12646350016958596, 0.1048185558687948, 0.05768368463236745,
               0.05656064291354508, 0.06232946593926463, 0.6731652230502976, 0.15139258333826097, 0.566280739064292,
               0.2927525484658312, 0.23831796671468414, 0.27785689727808466, 0.13489786785124486, 0.09275560771166316,
               0.0633216620575863, 0.1317239653479615] 

# Calculating the mean
lstm_v_mean_mae = np.mean(lstm_v_mae_values)
lstm_v_mean_mse = np.mean(lstm_v_mse_values)
lstm_v_mean_rmse = np.mean(lstm_v_rmse_values)

# Calculating the standard deviation
lstm_v_std_mae = np.std(lstm_v_mae_values)
lstm_v_std_mse = np.std(lstm_v_mse_values)
lstm_v_std_rmse = np.std(lstm_v_rmse_values)

# Calculating the IQR
lstm_v_iqr_mae = np.percentile(lstm_v_mae_values, 75) - np.percentile(lstm_v_mae_values, 25)
lstm_v_iqr_mse = np.percentile(lstm_v_mse_values, 75) - np.percentile(lstm_v_mse_values, 25)
lstm_v_iqr_rmse = np.percentile(lstm_v_rmse_values, 75) - np.percentile(lstm_v_rmse_values, 25)

# %% [markdown]
# ### GRU_U

# %%
gru_u_mae_values = [0.06369391806105301, 0.08611791909076945, 0.33627686768908777, 0.36910475253959246, 0.2354061561183162,
              0.04741513148697365, 0.05295655453706147, 0.07729110226036094, 0.09988715106960917, 0.07483920705650972,
              0.044185912577371846, 0.053153238509456247, 0.06627595238981361, 0.07049478505969478, 0.04981910283011657,
              0.09882352676259705, 0.08603763424563544, 0.12118943215287742, 0.054725603430460956, 0.0752536187046034,
              0.07654290328950066, 0.08694954228805192, 0.08977994997728572, 0.09020178603424271, 0.060824639124430376,
              0.13200519741382968, 0.06755307181700333, 0.04681145231035202, 0.2334801153457926, 0.09526555162508571,
              0.20078293667475666, 0.24079832863901526, 0.20793771311614706, 1.3910668646249047, 0.06501001432141862,
              0.08862283430869485, 0.15754158519702657]  

gru_u_mse_values = [0.005357023666220981, 0.00862929178746931, 0.14746383466383967, 0.20255348124765452, 0.0661829257934804,
              0.0030253243181394347, 0.00511299291744243, 0.009342323842254203, 0.01455570372042198, 0.007434723858846502,
              0.00268856217229353, 0.0043364135348198515, 0.005710203164061722, 0.006365855361696114, 0.0035250357635714645,
              0.012794267939996282, 0.010877914972413553, 0.018196267478582943, 0.006168775297026421, 0.007780860516323658,
              0.008364139870701181, 0.011459378186779041, 0.012999069965593621, 0.014117128627840538, 0.007447259699528374,
              0.022200074118830165, 0.0061762553406926775, 0.003297460017357563, 0.13796209024662193, 0.012133277441859608,
              0.0874277530306008, 0.15034697307570652, 0.10646555989072404, 3.121144029182729, 0.0045918201983689445,
              0.007854578577643767, 0.025797317130211782] 

gru_u_rmse_values = [0.07319169123760552, 0.09289398143835428, 0.384010201249706, 0.4500594196855061, 0.2572604240715629,
               0.055002948267701385, 0.07150519503813993, 0.09665569741227986, 0.12064702118337602, 0.08622484478876434,
               0.05185134687058312, 0.0658514505141675, 0.07556588624545948, 0.07978631061589522, 0.05937201161802979,
               0.11311174978752774, 0.10429724335960924, 0.1348935412782352, 0.07854155140450449, 0.08820918612210214,
               0.0914556716158226, 0.10704848521478032, 0.11401346396629487, 0.118815523513725, 0.08629750691374795,
               0.14899689298381413, 0.07858915536314585, 0.05742351449848366, 0.37143248410259155, 0.11015115724248932,
               0.29568184426947963, 0.38774601619579085, 0.32629060650089825, 1.7666759830774654, 0.06776297070206519,
               0.08862606037528559, 0.1606154324161031] 

# Calculating the mean
gru_u_mean_mae = np.mean(gru_u_mae_values)
gru_u_mean_mse = np.mean(gru_u_mse_values)
gru_u_mean_rmse = np.mean(gru_u_rmse_values)

# Calculating the standard deviation
gru_u_std_mae = np.std(gru_u_mae_values)
gru_u_std_mse = np.std(gru_u_mse_values)
gru_u_std_rmse = np.std(gru_u_rmse_values)

# Calculating the IQR
gru_u_iqr_mae = np.percentile(gru_u_mae_values, 75) - np.percentile(gru_u_mae_values, 25)
gru_u_iqr_mse = np.percentile(gru_u_mse_values, 75) - np.percentile(gru_u_mse_values, 25)
gru_u_iqr_rmse = np.percentile(gru_u_rmse_values, 75) - np.percentile(gru_u_rmse_values, 25)

# %% [markdown]
# ### GRU_V

# %%
gru_v_mae_values = [0.37341085434002186, 0.46694271712186125, 0.2762695375159209, 0.37327226664489466, 0.3567190461620555,
              0.08233805256088662, 0.054628682848035126, 0.07168731052257964, 0.0636717521778523, 0.05078945445286979,
              0.04030069103696648, 0.04062239896680249, 0.036206754770780065, 0.05986705775401533, 0.049350944946609805,
              0.04402287046081557, 0.04721633107043921, 0.051802994178011846, 0.05905438096898726, 0.05386045444035318,
              0.05165511302868425, 0.25828163485498296, 0.11081902221257102, 0.05071112343033476, 0.050688052350663725,
              0.05911981447489101, 0.053244317059304595, 0.5601553724627871, 0.15611919244424602, 0.35790664081368195,
              0.20677708220058064, 0.17459406696796717, 0.1846712836605936, 0.1998671440943817, 0.0919535653309481,
              0.015058168286198234, 0.12110587581741365]  

gru_v_mse_values = [0.20993729082983456, 0.3355771705121002, 0.11802170037388271, 0.2097746982659731, 0.1958442099861241,
              0.008936106051020565, 0.005763556193620214, 0.007766999261593538, 0.005416456107851746, 0.004502648684066577,
              0.0032366363303114043, 0.0035515304913159413, 0.0020460448518576737, 0.004852091127852805, 0.004165261401919859,
              0.003050476721249531, 0.003142327490317585, 0.004718990975612534, 0.00543312123953343, 0.003907172784742998,
              0.003875542339441401, 0.12656166856281265, 0.01771796767266973, 0.003940860408554975, 0.003428493336953086,
              0.005082923875854128, 0.0039518217728029955, 0.48460240254606934, 0.02820732526762947, 0.3169131642596796,
              0.08531971083699359, 0.057828546752600074, 0.07008227176738034, 0.05239823835097734, 0.010036797961255494,
              0.0003079949668924104, 0.016563434714910796] 

gru_v_rmse_values = [0.45818914307285213, 0.5792902299470449, 0.3435428654096643, 0.4580116791807531, 0.4425428905610439,
               0.09453097931906008, 0.07591808871158581, 0.08813058074013548, 0.07359657674003423, 0.06710177854622466,
               0.056891443383969474, 0.05959471865288015, 0.04523322729872006, 0.06965695319099742, 0.06453883638492298,
               0.05523112094869641, 0.056056466980336755, 0.06869491229787351, 0.07370970926230432, 0.06250738184201125,
               0.06225385401275491, 0.35575506821802644, 0.13310885647720713, 0.06277627265579706, 0.05855333753897455,
               0.07129462725797876, 0.06286351702540191, 0.6961338969954483, 0.1679503654882283, 0.5629504101247992,
               0.29209537969128097, 0.24047566769342812, 0.2647305644752421, 0.22890661491310674, 0.10018382085574244,
               0.017549785380237857, 0.1286990082126152] 

# Calculating the mean
gru_v_mean_mae = np.mean(gru_v_mae_values)
gru_v_mean_mse = np.mean(gru_v_mse_values)
gru_v_mean_rmse = np.mean(gru_v_rmse_values)

# Calculating the standard deviation
gru_v_std_mae = np.std(gru_v_mae_values)
gru_v_std_mse = np.std(gru_v_mse_values)
gru_v_std_rmse = np.std(gru_v_rmse_values)

# Calculating the IQR
gru_v_iqr_mae = np.percentile(gru_v_mae_values, 75) - np.percentile(gru_v_mae_values, 25)
gru_v_iqr_mse = np.percentile(gru_v_mse_values, 75) - np.percentile(gru_v_mse_values, 25)
gru_v_iqr_rmse = np.percentile(gru_v_rmse_values, 75) - np.percentile(gru_v_rmse_values, 25)

# %% [markdown]
# ### Print Results

# %%
print("\n==================================================================================")
print("LSTM 'u':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{lstm_u_mean_mae:<25}{lstm_u_std_mae:<25}{lstm_u_iqr_mae:<25}")
print(f"{'MSE':<10}{lstm_u_mean_mse:<25}{lstm_u_std_mse:<25}{lstm_u_iqr_mse:<25}")
print(f"{'RMSE':<10}{lstm_u_mean_rmse:<25}{lstm_u_std_rmse:<25}{lstm_u_iqr_rmse:<25}")

print("\n==================================================================================")
print("LSTM 'v':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{lstm_v_mean_mae:<25}{lstm_v_std_mae:<25}{lstm_v_iqr_mae:<25}")
print(f"{'MSE':<10}{lstm_v_mean_mse:<25}{lstm_v_std_mse:<25}{lstm_v_iqr_mse:<25}")
print(f"{'RMSE':<10}{lstm_v_mean_rmse:<25}{lstm_v_std_rmse:<25}{lstm_v_iqr_rmse:<25}")

print("\n==================================================================================")
print("GRU 'u':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{gru_u_mean_mae:<25}{gru_u_std_mae:<25}{gru_u_iqr_mae:<25}")
print(f"{'MSE':<10}{gru_u_mean_mse:<25}{gru_u_std_mse:<25}{gru_u_iqr_mse:<25}")
print(f"{'RMSE':<10}{gru_u_mean_rmse:<25}{gru_u_std_rmse:<25}{gru_u_iqr_rmse:<25}")

print("\n==================================================================================")
print("GRU 'v':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{gru_v_mean_mae:<25}{gru_v_std_mae:<25}{gru_v_iqr_mae:<25}")
print(f"{'MSE':<10}{gru_v_mean_mse:<25}{gru_v_std_mse:<25}{gru_v_iqr_mse:<25}")
print(f"{'RMSE':<10}{gru_v_mean_rmse:<25}{gru_v_std_rmse:<25}{gru_v_iqr_rmse:<25}")
print("==================================================================================")
# Out:
# ...
# LSTM 'u':
# Metric    Mean                     Std Dev                  IQR
# MAE       0.14125946248567997      0.2265831724081127       0.058301447517100494
# MSE       0.11692609396936171      0.5132824073724478       0.010115402032896504
# RMSE      0.1795733102624883       0.29099745739565114      0.05289318629993246
#
# ...
# LSTM 'v':
# Metric    Mean                     Std Dev                  IQR
# MAE       0.14369923815926253      0.13416186874255337      0.1407154132910573
# MSE       0.06405462684653777      0.10900010672303224      0.07281455303397251
# RMSE      0.18299755039882487      0.17483284415282882      0.21160055923385238
#
# ...
# GRU 'u':
# Metric    Mean                     Std Dev                  IQR
# MAE       0.14848978520755404      0.22170805613768949      0.06699518309241106
# MSE       0.11588880936806335      0.5033877277710723       0.016031298821803742
# RMSE      0.18693390462543497      0.2845075125010799       0.07045534157930965
#
# ...
# GRU 'v':
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Model Evaluation for 4th of November 2023 Prediction

# %% [markdown]
# ### LSTM_U

# %%
lstm_u_mae_values = [0.7055804565224567, 0.3944681274436399, 0.38666356240002714, 7.191481728133667, 8.071516150330572, 
                     0.11038885667522667, 0.2950900033125596, 6.91810945921273, 5.051334886768568, 0.10145743464590706, 
                     0.08704207657031841, 1.0913755249318742, 0.8774882758116824, 0.07705371010526409, 0.08435457202695418, 
                     0.11060610610131742, 0.13282019111155394, 0.1399384754525402, 0.07948175819731705, 0.17822341336109707,
                     0.1552369203331379, 0.135769926036162, 0.1395468931136249, 0.08144840934565381, 0.08798038701043638, 
                     0.05057205888112678, 0.06406798597840323, 0.36175103631002953, 0.09523901602402927, 0.11448995848398251, 
                     0.22840088972311065, 0.11397238517630405, 0.09864302189808678, 0.036445237534373544, 3.331717603273957,
                     0.8242917173350909, 0.1582041594692021]  

lstm_u_mse_values = [0.5662704542421818, 0.1714041867979248, 0.17573269002132164, 134.65945545685724, 171.79942047456484, 
                     0.016503016613487936, 0.25489215978283813, 126.62540329587377, 66.85423542670759, 0.011538810071480686, 
                     0.009358652197545204, 3.277865370747452, 2.3147486076196375, 0.0070883191594906525, 0.00815439055146483, 
                     0.013297533023349161, 0.01926158396896403, 0.021931565762735163, 0.0072340481879504355, 0.034105429414226916, 
                     0.025710977865980613, 0.02429134490282862, 0.02472358983382061, 0.008043868867380795, 0.008870386523154337, 
                     0.003263216019585638, 0.004444177637448563, 0.14167511080580367, 0.011775629355759112, 0.01639485957714202, 
                     0.10370535395574938, 0.01610007804599829, 0.011988436229462196, 0.0019030416160953835, 36.840701736392646, 
                     2.1850640116898905, 0.031628943259484975] 

lstm_u_rmse_values = [0.752509437975486, 0.4140098873190407, 0.41920483062736963, 11.604286081308805, 13.10722779517335,
                      0.12846406740208693, 0.5048684579005092, 11.252795354749582, 8.17644393527575, 0.10741885342657817,
                      0.09674012713215341, 1.8104876057978005, 1.5214297905653213, 0.08419215616368696, 0.09030166416774849,
                      0.11531492975044108, 0.13878610870315528, 0.14809309829541403, 0.0850532079815361, 0.1846765535043009,
                      0.1603464307865336, 0.15585680897166032, 0.15723736780365097, 0.08968761825012857, 0.09418272943143205,
                      0.05712456581529209, 0.06666466558416508, 0.3763975435703635, 0.10851557195056898, 0.12804241319633905,
                      0.32203315660929915, 0.1268860829484396, 0.10949171762951843, 0.043623865212695026, 6.069654169422888,
                      1.4781962020279618, 0.1778452789912765] 

# Calculating the mean
lstm_u_mean_mae = np.mean(lstm_u_mae_values)
lstm_u_mean_mse = np.mean(lstm_u_mse_values)
lstm_u_mean_rmse = np.mean(lstm_u_rmse_values)

# Calculating the standard deviation
lstm_u_std_mae = np.std(lstm_u_mae_values)
lstm_u_std_mse = np.std(lstm_u_mse_values)
lstm_u_std_rmse = np.std(lstm_u_rmse_values)

# Calculating the IQR
lstm_u_iqr_mae = np.percentile(lstm_u_mae_values, 75) - np.percentile(lstm_u_mae_values, 25)
lstm_u_iqr_mse = np.percentile(lstm_u_mse_values, 75) - np.percentile(lstm_u_mse_values, 25)
lstm_u_iqr_rmse = np.percentile(lstm_u_rmse_values, 75) - np.percentile(lstm_u_rmse_values, 25)

# %% [markdown]
# ### LSTM_V

# %%
lstm_v_mae_values = [0.9301522650307805, 0.327056398475794, 0.5353526289189826, 17.19514705608071, 19.89693482714939,
                     0.12762783511943662, 9.061840787318408, 16.41889935189406, 16.54866393864408, 0.05326064963517887,
                     0.1470973630674817, 4.67637808358063, 4.2909786488674335, 0.06539202382266275, 0.09215566012959342,
                     0.0856865681633201, 0.08240410952073447, 0.08884647073133374, 0.11316974855996802, 0.08014743600048362,
                     0.048875357181140965, 0.07126951839997549, 0.0857645229154188, 0.06942243589831716, 0.0809684675331759,
                     0.07198243136884809, 0.07355416985636067, 0.23542594811427112, 0.050712643636869115, 0.06848049335368772,
                     0.10447901321365849, 0.05479736456714169, 0.07409863392763064, 0.19242811777214008, 4.143168986611097,
                     0.5797234005392875, 0.17818368589578415]  

lstm_v_mse_values = [0.8681343633178589, 0.16972042436743717, 0.4146940494819124, 763.7682612130342, 1037.7464522380315,
                     0.020736702335420465, 215.54427583179634, 705.1106941304537, 718.5245656091496, 0.0032830528511944034,
                     0.027803995891891916, 65.06889963454603, 55.0642874760023, 0.005206760169633512, 0.011039954849219873,
                     0.011177628083890145, 0.010278707923875778, 0.009548466440918177, 0.01649434534427509, 0.008450925036562565,
                     0.0036717574128472077, 0.006484695075016135, 0.009113710427522783, 0.006472437072233266, 0.009150384234663847,
                     0.007620376233498305, 0.007694467452105743, 0.09572639913127733, 0.003567581568670927, 0.005638442086106046,
                     0.016343011141612088, 0.005857031206299402, 0.006827404494533143, 0.04738255456064968, 56.94081324299915,
                     1.090690442436199, 0.07369036054785338] 

lstm_v_rmse_values = [0.9317372823483339, 0.4119713878019166, 0.6439674288983197, 27.636357596706446, 32.2140722703298,
                      0.14400243864400514, 14.68142621926754, 26.553920503956732, 26.805308534115955, 0.057297930601326284,
                      0.16674530245824593, 8.066529590508301, 7.420531482043742, 0.07215788362773337, 0.10507118943468696,
                      0.10572430223884263, 0.10138396285347982, 0.0977162547425871, 0.1284303131829674, 0.09192891295214235,
                      0.060595027954834776, 0.08052760442864382, 0.09546575526084096, 0.08045145786269672, 0.09565764075422227,
                      0.08729476635800285, 0.08771811359181034, 0.30939683115907524, 0.05972923546029136, 0.07508956043356524,
                      0.1278397870055019, 0.07653124333433635, 0.0826281095907025, 0.2176753421052777, 7.545913678475202,
                      1.0443612605014603, 0.2714596849402382] 

# Calculating the mean
lstm_v_mean_mae = np.mean(lstm_v_mae_values)
lstm_v_mean_mse = np.mean(lstm_v_mse_values)
lstm_v_mean_rmse = np.mean(lstm_v_rmse_values)

# Calculating the standard deviation
lstm_v_std_mae = np.std(lstm_v_mae_values)
lstm_v_std_mse = np.std(lstm_v_mse_values)
lstm_v_std_rmse = np.std(lstm_v_rmse_values)

# Calculating the IQR
lstm_v_iqr_mae = np.percentile(lstm_v_mae_values, 75) - np.percentile(lstm_v_mae_values, 25)
lstm_v_iqr_mse = np.percentile(lstm_v_mse_values, 75) - np.percentile(lstm_v_mse_values, 25)
lstm_v_iqr_rmse = np.percentile(lstm_v_rmse_values, 75) - np.percentile(lstm_v_rmse_values, 25)

# %% [markdown]
# ### GRU_U

# %%
gru_u_mae_values = [0.728949606137824, 0.6416110229565436, 0.19667792531000725, 7.2225932235419394, 8.082857336056719,
                    0.11879316001733063, 0.29591319126479987, 6.891089407061905, 5.005637297383089, 0.08702841711065103,
                    0.09472986054500691, 1.113385991529926, 0.916764903346747, 0.13117321136816731, 0.08334478024793275,
                    0.19139908286654062, 0.18612933117879105, 0.16854706690353938, 0.07833559440589898, 0.16354947633631559,
                    0.17066332638789547, 0.12173460666998011, 0.07344230621703778, 0.05849204030795202, 0.0746218294136337,
                    0.20697903981633395, 0.1321389144029417, 0.6629338168024596, 0.07971830088601402, 0.09293589411111203,
                    0.2523438147590642, 0.09936784298009498, 0.09685082532030664, 0.03828997088922456, 3.3403252377141768,
                    0.823946739465749, 0.16731258033063937]  

gru_u_mse_values = [0.5616518709092254, 0.4346513228683396, 0.04366302981859022, 135.31215749262128, 172.2238754835203,
                    0.018459556616203646, 0.25549127338356936, 126.0299694718321, 65.98106982051964, 0.008710870505841573,
                    0.010916426548233523, 3.3230801693698755, 2.417975032815509, 0.018802395278724654, 0.007943929383835811,
                    0.03950318097997726, 0.03722891624238612, 0.030614740918859587, 0.007039746804182896, 0.028849586379513764,
                    0.031065187800984616, 0.018898289811520707, 0.006786312295387596, 0.004469133920122523, 0.006314205850113985,
                    0.046681234705936624, 0.019525198424944934, 0.4772626612581339, 0.008040603726861153, 0.010649438895399007,
                    0.11736108706795724, 0.012206990236849338, 0.011804821167414404, 0.002065863165838729, 36.82030024274905,
                    2.1604831573915653, 0.03088320144631661] 

gru_u_rmse_values = [0.7494343673125923, 0.6592809134718974, 0.20895700471290793, 11.632375401981372, 13.12340944585363,
                     0.13586595090825238, 0.505461445991254, 11.226307027327914, 8.122873249073855, 0.0933320443676317,
                     0.10448170437083003, 1.8229317511552305, 1.5549839332981898, 0.13712182641259069, 0.08912872367444634,
                     0.19875407160603592, 0.1929479625245784, 0.1749706858844063, 0.08390319901042448, 0.16985165992569448,
                     0.1762531923143085, 0.13747105081260094, 0.08237907680587102, 0.06685158128363548, 0.07946197738613094,
                     0.21605840577477337, 0.1397325961432941, 0.6908419944228448, 0.08966941355256626, 0.10319611860626836,
                     0.3425800447602826, 0.11048524895590967, 0.10864999386753045, 0.04545176746660936, 6.067973322514614,
                     1.4698582099616158, 0.17573617000013575] 

# Calculating the mean
gru_u_mean_mae = np.mean(gru_u_mae_values)
gru_u_mean_mse = np.mean(gru_u_mse_values)
gru_u_mean_rmse = np.mean(gru_u_rmse_values)

# Calculating the standard deviation
gru_u_std_mae = np.std(gru_u_mae_values)
gru_u_std_mse = np.std(gru_u_mse_values)
gru_u_std_rmse = np.std(gru_u_rmse_values)

# Calculating the IQR
gru_u_iqr_mae = np.percentile(gru_u_mae_values, 75) - np.percentile(gru_u_mae_values, 25)
gru_u_iqr_mse = np.percentile(gru_u_mse_values, 75) - np.percentile(gru_u_mse_values, 25)
gru_u_iqr_rmse = np.percentile(gru_u_rmse_values, 75) - np.percentile(gru_u_rmse_values, 25)

# %% [markdown]
# ### GRU_V

# %%
gru_v_mae_values = [0.3396227829618126, 0.3504029514059963, 0.42948831353673916, 17.201998859378666, 19.93114674260846,
                    0.10287281461442259, 9.081987812593141, 16.42568461601636, 16.553912808607382, 0.050013744197818656,
                    0.10549616151304901, 4.681749393397467, 4.301296022927054, 0.0643871491632453, 0.07752280227868542, 
                    0.10381595358902929, 0.05355954085036674, 0.10396162651652584, 0.11617936063051977, 0.07103940622888744, 
                    0.05757545272876848, 0.06978422051079165, 0.07945748505774723, 0.12144120973062962, 0.0945624326254706,
                    0.09326897291410345, 0.09191757849540703, 0.489384123693978, 0.05154913577428517, 0.07093178698980113, 
                    0.09349478661804811, 0.059213409043176374, 0.06489240861673568, 1.3652329284997762, 4.143594718840002, 
                    0.608312247044919, 0.46608828813841785]  

gru_v_mse_values = [0.14043924442818564, 0.1534723731269054, 0.22306127720543653, 763.6998223340066, 1039.2253065727816,
                    0.01552339283111133, 215.9264052846502, 705.9219429109603, 718.6888146513393, 0.003078879012795474,
                    0.014718077641301439, 65.01476593272359, 55.066250940929855, 0.005188660663788524, 0.008042434708539789,
                    0.015885196303064526, 0.005596532162438454, 0.01389487944487989, 0.017630693059499516, 0.006617251628720803,
                    0.005092797231739796, 0.00632709744711965, 0.007579762040900116, 0.01847869892021159, 0.012283709409423568,
                    0.012767376332424396, 0.012644693352056693, 0.24506874983478166, 0.004547064312374952, 0.0060033799956240586,
                    0.01250565919718036, 0.005631309094132282, 0.006136893067059499, 2.3062303012098337, 57.047843774234906,
                    1.1504113860089038, 0.24424526475170874] 

gru_v_rmse_values = [0.37475224406023994, 0.39175550171874474, 0.47229363451716827, 27.63511936529326, 32.23701764389475,
                     0.1245929084302607, 14.6944345003355, 26.569191611920758, 26.808372099986588, 0.05548764738926561,
                     0.1213180845599758, 8.063173440570628, 7.420663780345385, 0.0720323584494394, 0.08967962259365161,
                     0.1260364879829033, 0.07480997368291513, 0.1178765432343513, 0.13278062004486768, 0.08134649118874644,
                     0.07136383700264298, 0.07954305404697289, 0.08706182883962475, 0.13593637820764384, 0.11083189707581283,
                     0.11299281540179622, 0.11244862538980498, 0.49504418977984344, 0.06743192354052309, 0.07748148163028414,
                     0.11182870471028608, 0.07504204884018215, 0.07833832438251088, 1.518627769142206, 7.553002302014406,
                     1.0725723220412242, 0.4942117610414677] 

# Calculating the mean
gru_v_mean_mae = np.mean(gru_v_mae_values)
gru_v_mean_mse = np.mean(gru_v_mse_values)
gru_v_mean_rmse = np.mean(gru_v_rmse_values)

# Calculating the standard deviation
gru_v_std_mae = np.std(gru_v_mae_values)
gru_v_std_mse = np.std(gru_v_mse_values)
gru_v_std_rmse = np.std(gru_v_rmse_values)

# Calculating the IQR
gru_v_iqr_mae = np.percentile(gru_v_mae_values, 75) - np.percentile(gru_v_mae_values, 25)
gru_v_iqr_mse = np.percentile(gru_v_mse_values, 75) - np.percentile(gru_v_mse_values, 25)
gru_v_iqr_rmse = np.percentile(gru_v_rmse_values, 75) - np.percentile(gru_v_rmse_values, 25)

# %% [markdown]
# ### Print Results

# %%
print("\n==================================================================================")
print("LSTM 'u':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{lstm_u_mean_mae:<25}{lstm_u_std_mae:<25}{lstm_u_iqr_mae:<25}")
print(f"{'MSE':<10}{lstm_u_mean_mse:<25}{lstm_u_std_mse:<25}{lstm_u_iqr_mse:<25}")
print(f"{'RMSE':<10}{lstm_u_mean_rmse:<25}{lstm_u_std_rmse:<25}{lstm_u_iqr_rmse:<25}")

print("\n==================================================================================")
print("LSTM 'v':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{lstm_v_mean_mae:<25}{lstm_v_std_mae:<25}{lstm_v_iqr_mae:<25}")
print(f"{'MSE':<10}{lstm_v_mean_mse:<25}{lstm_v_std_mse:<25}{lstm_v_iqr_mse:<25}")
print(f"{'RMSE':<10}{lstm_v_mean_rmse:<25}{lstm_v_std_rmse:<25}{lstm_v_iqr_rmse:<25}")

print("\n==================================================================================")
print("GRU 'u':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{gru_u_mean_mae:<25}{gru_u_std_mae:<25}{gru_u_iqr_mae:<25}")
print(f"{'MSE':<10}{gru_u_mean_mse:<25}{gru_u_std_mse:<25}{gru_u_iqr_mse:<25}")
print(f"{'RMSE':<10}{gru_u_mean_rmse:<25}{gru_u_std_rmse:<25}{gru_u_iqr_rmse:<25}")

print("\n==================================================================================")
print("GRU 'v':")
print(f"{'Metric':<10}{'Mean':<25}{'Std Dev':<25}{'IQR':<25}")
print(f"{'MAE':<10}{gru_v_mean_mae:<25}{gru_v_std_mae:<25}{gru_v_iqr_mae:<25}")
print(f"{'MSE':<10}{gru_v_mean_mse:<25}{gru_v_std_mse:<25}{gru_v_iqr_mse:<25}")
print(f"{'RMSE':<10}{gru_v_mean_rmse:<25}{gru_v_std_rmse:<25}{gru_v_iqr_rmse:<25}")
print("==================================================================================")
# Out:
# ...
# LSTM 'u':
# Metric    Mean                     Std Dev                  IQR
# MAE       1.0314122263524859       2.1180108441087326       0.2992291114196106
# MSE       14.765086114452533       40.75768926145279        0.24335334971135744
# RMSE      1.6341645981465494       3.477728019931556        0.39744960447393096
#
# ...
# LSTM 'v':
# Metric    Mean                     Std Dev                  IQR
# MAE       2.621635865986359        5.507097811770127        0.5061692306829269
# MSE       97.85785810289697        253.4289258005508        0.8605139870843606
# RMSE      4.238773402322426        8.93815742458483         0.844442515990331
#
# ...
# GRU 'u':
# Metric    Mean                     Std Dev                  IQR
# MAE       1.0510974857309268       2.1118906465916236       0.5682039562574527
# MSE       14.77233653911434        40.77340238064917        0.46634623470990033
# RMSE      1.6510546630673708       3.4707859396220093       0.5863602900520147
#
# ...
# GRU 'v':
# ...

# %% [markdown]
# ---
